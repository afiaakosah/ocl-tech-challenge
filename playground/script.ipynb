# %%
import requests
from bs4 import BeautifulSoup

base_url = "https://valuation2022.durban.gov.za/FramePages/"
form_page_url = "SearchType.aspx"
form_action_url = "SearchType.aspx"
search_result_url = "SearchResult.aspx"

session = requests.session()

# %%
def extract_search_request_data(soup):
    post_data = {
        "__EVENTTARGET": "btnGo",
        "__EVENTARGUMENT": "",
    }
    input_fields = soup.findAll("input")

    for field in input_fields:
        post_data[field["name"]] = field["value"]

    select_name = soup.find("select")["name"]
    options = soup.findAll("option")

    # Make a dictionary of select options and remove the empty first option
    options = list(map(lambda option: option["value"], options))[1:3]

    selected_option = options[0]
    post_data[select_name] = selected_option
    post_data.pop("btnGo", None)

    return post_data

# %%
def get_results(data):
    post_response = session.post(base_url + form_action_url, data=data, verify=False)

    # Check if a redirect happens
    if post_response.status_code == 302 or "Location" in post_response.headers:
        redirect_url = post_response.headers["Location"]

        search_response = session.get(redirect_url)
        results_html = search_response.text
        search_results_soup = BeautifulSoup(results_html, "html.parser")
    else:
        search_results_soup = BeautifulSoup(post_response.text, "html.parser")

    parameters = "?Roll=1&VolumeNo=&RateNumber=534&StreetNo=&StreetName=&Suburb=&ERF=&Portion=&DeedsTown=&SchemeName=&SectionNumber=&All=false"
    search_data_response = session.get(
        base_url + search_result_url + parameters, verify=False
    ).content

    search_data_soup = BeautifulSoup(search_data_response, "html.parser")
    results_table = search_data_soup.find("table")

    # Initialize a list to store each row's data
    data = []

    # Extract table headings
    headers = [header.text.strip() for header in results_table.find_all("th")]

    for row in results_table.find_all("tr"):
        columns = row.find_all("td")
        if columns:
            data.append({headers[i]: col.text.strip() for i, col in enumerate(columns)})

    return data

# %%
import pandas as pd

def clean_data(data):
    # Load data into a DataFrame
    df = pd.DataFrame(data)

    # Remove non-numeric "Rate Number" entries
    df = df[df['Rate Number'].str.isnumeric()]

    # Normalize column names (convert to lowercase, replace spaces with underscores)
    df.columns = df.columns.str.lower().str.replace(" ", "_")

    # Convert "registered_extent" to numeric, handling commas and empty strings
    df['registered_extent'] = pd.to_numeric(df['registered_extent'].str.replace(",", ""), errors='coerce')

    # Replace empty strings with NaN (which maps to NULL in PostgreSQL)
    df.replace({"": None}, inplace=True)
    
    return df

# %%
from sqlalchemy import create_engine

def store_data_to_db(dataframe, db_name):
    # Create SQLite database
    engine = create_engine(f'sqlite:///{db_name}.db')

    # Insert data into SQLite
    dataframe.to_sql('properties', engine, if_exists='replace', index=False)

    print("Data successfully inserted into SQLite database.")

# %%
import sqlite3

def get_data_from_db(db_name):
    # Connect to the SQLite database
    conn = sqlite3.connect(f'{db_name}.db')

    # Query the database
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM properties")
    rows = cursor.fetchall()

    # Close the connection
    conn.close()
    
    return rows

# %%
# Get form page HTML
html = session.get(base_url + form_page_url, verify=False).content
# Prettify HTML output
mainPageSoup = BeautifulSoup(html)

search_form_data = extract_search_request_data(mainPageSoup)
result_data = get_results(search_form_data)
# Out:
# c:\Users\CHARL\.virtualenvs\challenge-scrap-Jm7KxQm2\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'valuation2022.durban.gov.za'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\CHARL\.virtualenvs\challenge-scrap-Jm7KxQm2\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'valuation2022.durban.gov.za'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\CHARL\.virtualenvs\challenge-scrap-Jm7KxQm2\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'valuation2022.durban.gov.za'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\CHARL\.virtualenvs\challenge-scrap-Jm7KxQm2\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'valuation2022.durban.gov.za'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
dataframe = clean_data(result_data)
dataframe.head()
# Out:
#   rate_number       legal_description                      address  \
# 2    96150534   ERF 18288 of PINETOWN   10 211589 STREET, PINETOWN
# 3    51534286     ERF 195 of ELANGENI       19 400356, HAMMARSDALE
# 4    65345130   ERF 393 of KLAARWATER  13 40533 STREET, KLAARWATER
# 5    43534177  ERF 65 of MPUMALANGA H  35 645 STREET, MPUMALANGA-H
# 6    53400055        ERF 2280 of LOVU        11 10404 STREET, LOVU
#
#                           first_owner                 use_code  \
# 2                   RAJKUMAR DAYANAND         Vacant Land (47)
# 3  BLACK S TRANSPORT AND LOGISTICS CC         Vacant Land (47)
# 4                         NENE PETROS  Single Residential (15)
# 5       NTSHANGASE MZIKAYIFANI JOSEPH  Single Residential (15)
# 6            MEMELA XOLISILE JENNIFER  Single Residential (15)
#
#   rating_category market_value  registered_extent
# 2     Vacant Land       50,000                399
# 3     Vacant Land       33,000               1084
# 4     Residential      240,000                425
# 5     Residential      450,000                389
# 6     Residential      150,000                301

# %%
db_name = "properties"
store_data_to_db(dataframe, db_name)
# Out:
# Data successfully inserted into SQLite database.

# %%
rows = get_data_from_db(db_name)
rows
# Out:
# [('96150534',
#   'ERF 18288 of PINETOWN',
#   '10 211589 STREET, PINETOWN',
#   'RAJKUMAR DAYANAND',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '50,000',
#   399),
#  ('51534286',
#   'ERF 195 of ELANGENI',
#   '19 400356, HAMMARSDALE',
#   'BLACK S TRANSPORT AND LOGISTICS CC',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '33,000',
#   1084),
#  ('65345130',
#   'ERF 393 of KLAARWATER',
#   '13 40533 STREET, KLAARWATER',
#   'NENE PETROS',
#   'Single Residential (15)',
#   'Residential',
#   '240,000',
#   425),
#  ('43534177',
#   'ERF 65 of MPUMALANGA H',
#   '35 645 STREET, MPUMALANGA-H',
#   'NTSHANGASE MZIKAYIFANI JOSEPH',
#   'Single Residential (15)',
#   'Residential',
#   '450,000',
#   389),
#  ('53400055',
#   'ERF 2280 of LOVU',
#   '11 10404 STREET, LOVU',
#   'MEMELA XOLISILE JENNIFER',
#   'Single Residential (15)',
#   'Residential',
#   '150,000',
#   301),
#  ('53408136',
#   'ERF 2304 of LOVU',
#   '20 10405 STREET, LOVU',
#   'NZIMANDE SIBONELO TRUEMAN',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '100,000',
#   435),
#  ('53416317',
#   'ERF 2374 of LOVU',
#   '124 10080 STREET, LOVU',
#   'NGUBO THEMBISILE EMELTRUDIS',
#   'Single Residential (15)',
#   'Residential',
#   '160,000',
#   205),
#  ('53430153',
#   'ERF 2417 of LOVU',
#   '18 10081 STREET, LOVU',
#   'DLAMINI THOKOZILE',
#   'Single Residential (15)',
#   'Residential',
#   '510,000',
#   282),
#  ('53442273',
#   'ERF 2428 of LOVU',
#   '94 10080 STREET, LOVU',
#   'NTINGA EUNICE TIKO',
#   'Single Residential (15)',
#   'Residential',
#   '160,000',
#   254),
#  ('53456111',
#   'ERF 2453 of LOVU',
#   '10 10086 STREET, LOVU',
#   "DLAMINI SIPHAMANDLA S'KHUMBUZO",
#   'Single Residential (15)',
#   'Residential',
#   '160,000',
#   300),
#  ('53470149',
#   'ERF 2478 of LOVU',
#   '109 10080 STREET, LOVU',
#   'MBESA MAVUKA ERNEST',
#   'Single Residential (15)',
#   'Residential',
#   '130,000',
#   205),
#  ('53480249',
#   'ERF 2500 of LOVU',
#   '12 10158 STREET, LOVU',
#   'KHESWA SABANI TERISINA',
#   'Single Residential (15)',
#   'Residential',
#   '180,000',
#   518),
#  ('53492167',
#   'ERF 2541 of LOVU',
#   '93 10087 STREET, LOVU',
#   'HADEBE POPI JESSIE',
#   'Single Residential (15)',
#   'Residential',
#   '160,000',
#   329),
#  ('53498329',
#   'ERF 2553 of LOVU',
#   '3 10094 STREET, LOVU',
#   'JACA DINGINDOWO',
#   'Single Residential (15)',
#   'Residential',
#   '150,000',
#   300),
#  ('53446114',
#   'ERF 1570 of VERULAM EXT 16',
#   '53 JACARANDA AVENUE, MOUNTVIEW',
#   'RAMSAMY SUNDRAMMAH',
#   'Single Residential (15)',
#   'Residential',
#   '470,000',
#   335),
#  ('53462172',
#   'ERF 1578 of VERULAM EXT 16',
#   '69 JACARANDA AVENUE, MOUNTVIEW',
#   'CHOONILALL RAJESH',
#   'Single Residential (15)',
#   'Residential',
#   '420,000',
#   360),
#  ('53478131',
#   'ERF 1586 of VERULAM EXT 16',
#   '85 JACARANDA AVENUE, MOUNTVIEW',
#   'VERUTHAN SUGANANTHAN',
#   'Single Residential (15)',
#   'Residential',
#   '420,000',
#   342),
#  ('53490149',
#   'ERF 1592 of VERULAM EXT 16',
#   '38 GREENFIELD WAY, MOUNTVIEW',
#   'SOOBIAH KEVIN',
#   'Single Residential (15)',
#   'Residential',
#   '420,000',
#   151),
#  ('65534401',
#   'ERF 344 of MALUKAZI',
#   '26 NKUNDLENI GROVE, MALUKAZI',
#   'THUSI THULISILE REJOICE',
#   'Single Residential (15)',
#   'Residential',
#   '110,000',
#   250),
#  ('63953447',
#   'ERF 549 of UMLAZI Y',
#   '129 KWAMPISI DRIVE, UMLAZI-Y',
#   'NZUZA KHONANGANI',
#   'Single Residential (15)',
#   'Residential',
#   '370,000',
#   495),
#  ('62175343',
#   'ERF 1551 of UMLAZI N',
#   '10 EMASISWENI AVENUE, UMLAZI-N',
#   'KWAZULU GOVERNMENT',
#   'Single Residential (15)',
#   'Residential',
#   '350,000',
#   152),
#  ('62053436',
#   'ERF 209 of UMLAZI N',
#   '44 MAPONYA STREET, UMLAZI-N',
#   'MAGWAZA THEODOTHUS SIPHO',
#   'Single Residential (15)',
#   'Residential',
#   '610,000',
#   373),
#  ('60125346',
#   'ERF 1341 of UMLAZI AA',
#   '67 KEKANA AVENUE, UMLAZI-AA',
#   'LANGA ZWELINJANI PHENIAS',
#   'Single Residential (15)',
#   'Residential',
#   '370,000',
#   212),
#  ('50095341',
#   'ERF 805 of KWAMASHU B',
#   '17 NDLAMU ROAD, KWAMASHU-B',
#   'MLANGENI KHONI JOSHUA',
#   'Single Residential (15)',
#   'Residential',
#   '530,000',
#   427),
#  ('50025348',
#   'ERF 105 of KWAMASHU B',
#   '18 SONGO ROAD, KWAMASHU-B',
#   'XULU SIYABONGA NJABULO',
#   'Single Residential (15)',
#   'Residential',
#   '410,000',
#   265),
#  ('30895343',
#   'ERF 771 of NTUZUMA F',
#   '457 ITHENDELE DRIVE, NTUZUMA-F',
#   'ZULU ALIAN JOYCE',
#   'Single Residential (15)',
#   'Residential',
#   '350,000',
#   341),
#  ('60035340',
#   'ERF 354 of NHLUNGWANE',
#   '74 108476 STREET, NHLUNGWANE',
#   'MBATHA MZILIKAZI',
#   'Single Residential (15)',
#   'Residential',
#   '120,000',
#   371),
#  ('96153461',
#   'Portion 1 of ERF 12 of CHELMSFORDVILLE',
#   '14 EDWARD DRIVE, CHELMSFORDVILLE',
#   'SCHARNECK DEREK DONAVAN',
#   'Single Residential (15)',
#   'Residential',
#   '2,080,000',
#   2531),
#  ('53413899',
#   'ERF 1966 of NTUZUMA G',
#   '39 MDUDUZI SISHI GROVE, NTUZUMA - G',
#   'ETHEKWINI MUNICIPALITY',
#   'Single Residential (15)',
#   'Residential',
#   '180,000',
#   268),
#  ('15343059',
#   'ERF 2569 of PINETOWN',
#   '37 LANGWOOD ROAD, PINETOWN',
#   'ROUX MARGUERITA ROSALEE LE',
#   'Single Residential (15)',
#   'Residential',
#   '1,770,000',
#   2024),
#  ('34534170',
#   'Portion 2 of ERF 2154 of WESTVILLE',
#   '7 MKHULA ROAD, ERIN-GO-BRAGTH',
#   'PRICE JASON ROBERT',
#   'Single Residential (15)',
#   'Residential',
#   '1,880,000',
#   1834),
#  ('35347120',
#   'REM of ERF 200 of BEREA WEST',
#   '11 WINDSOR AVENUE, BEREA WEST',
#   'NAICKER VENAI',
#   'Single Residential (15)',
#   'Residential',
#   '2,260,000',
#   2255),
#  ('05345069',
#   'ERF 24559 of PINETOWN EXT 141',
#   '35 OLEANDER ROAD, MADIBA VALLEY',
#   'KHATHI SYLVIA BUSISIWE',
#   'Single Residential (15)',
#   'Residential',
#   '82,000',
#   448),
#  ('03534036',
#   'REM of ERF 293 of FOREST HILLS',
#   '22A VALLEY DRIVE, FOREST HILLS',
#   'DOBROWSKY DOUGLAS VAUGHAN',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '570,000',
#   6654),
#  ('53412179',
#   'ERF 824 of BOTHAS HILL',
#   '66013 STREET, QUADI SOUTH 2',
#   'MADLALA NTOMBI ANNASTASIA',
#   'Single Residential (15)',
#   'Residential',
#   '63,000',
#   300),
#  ('53426219',
#   'ERF 832 of BOTHAS HILL',
#   '66012 STREET, QUADI SOUTH 2',
#   'TEMBE MABUYELA DUMISANI',
#   'Single Residential (15)',
#   'Residential',
#   '63,000',
#   363),
#  ('53442176',
#   'ERF 840 of BOTHAS HILL',
#   '66013 STREET, QUADI SOUTH 2',
#   'DLAMINI MASANGO SIMON',
#   'Single Residential (15)',
#   'Residential',
#   '63,000',
#   300),
#  ('53456115',
#   'ERF 848 of BOTHAS HILL',
#   '66013 STREET, QUADI SOUTH 2',
#   'DLADLA PHILISIWE ROSEBEAM',
#   'Single Residential (15)',
#   'Residential',
#   '63,000',
#   300),
#  ('53470153',
#   'ERF 861 of BOTHAS HILL',
#   '66013 STREET, QUADI SOUTH 2',
#   'NGCOBO BASEBENZANI EUNICE',
#   'Single Residential (15)',
#   'Residential',
#   '63,000',
#   300),
#  ('53484192',
#   'ERF 870 of BOTHAS HILL',
#   '66013 STREET, QUADI SOUTH 2',
#   'GASA DUDUZILE PRINCESS',
#   'Single Residential (15)',
#   'Residential',
#   '63,000',
#   300),
#  ('53534187',
#   'ERF 897 of BOTHAS HILL',
#   ', QUADI SOUTH 2',
#   'NGCOBO ZIBUYILE MAUREEN',
#   'Single Residential (15)',
#   'Residential',
#   '63,000',
#   326),
#  ('08534138',
#   'ERF 3645 of ISIPINGO EXT 24',
#   '30 ACALYPHA CRESCENT, LOTUS PARK',
#   'LOTUS PARK ISLAMIC TRUST-TRUSTEES',
#   'Place of Worship (10)',
#   'Business & Commercial',
#   '4,720,000',
#   1319),
#  ('13534145',
#   'REM of Portion 209 of ERF 1575 of COTTON LANDS NO. 1575',
#   ', TONGAAT BEACH RURAL',
#   'KALWENI FARM CC',
#   'Agricultural (77)',
#   'Agricultural',
#   '140,000',
#   3726),
#  ('45344196',
#   'ERF 3052 of WATERLOO EXT 11',
#   '2 SOCCER AVENUE, WATERLOO',
#   'KHUBISA MSAWENKOSI',
#   'Single Residential (15)',
#   'Residential',
#   '220,000',
#   162),
#  ('63534904',
#   'ERF 2042 of UMLAZI Z',
#   '5 IMFE CLOSE, UMLAZI-Z',
#   'TIJI THULANI CYPRIAN',
#   'Single Residential (15)',
#   'Residential',
#   '440,000',
#   424),
#  ('61534396',
#   'ERF 2356 of UMLAZI H',
#   '18 107904 STREET, UMLAZI-H',
#   'KWAZULU GOVERNMENT',
#   'Single Residential (15)',
#   'Residential',
#   '280,000',
#   436),
#  ('61376534',
#   'ERF 572 of UMLAZI H',
#   '16 ISANDLWANA STREET, UMLAZI-H',
#   'A K MADLALA',
#   'Single Residential (15)',
#   'Residential',
#   '340,000',
#   455),
#  ('51534691',
#   'ERF 705 of KWAMASHU L',
#   '3 QOBOLO ROAD, KWAMASHU-L',
#   'KWAZULU GOVERNMENT',
#   'Single Residential (15)',
#   'Residential',
#   '190,000',
#   407),
#  ('33534473',
#   'ERF 322 of EMAPLAZINI',
#   '5 109817 STREET, EMAPLAZINI',
#   'NZAMA YVONNE',
#   'Single Residential (15)',
#   'Residential',
#   '120,000',
#   123),
#  ('33053411',
#   'ERF 534 of INANDA GLEBE',
#   '18 108773 STREET, INANDA GLEBE',
#   'NDAWONDE NKOSINATHI DESTER',
#   'Single Residential (15)',
#   'Residential',
#   '290,000',
#   596),
#  ('30534369',
#   'ERF 489 of NTUZUMA C',
#   '7 106587 STREET, NTUZUMA-C',
#   'KWAZULU GOVERNMENT',
#   'Single Residential (15)',
#   'Residential',
#   '170,000',
#   300),
#  ('60317534',
#   'ERF 2076 of EZIMANGWENI EXT 8',
#   '39 108980 STREET, EZIMANGWENI',
#   'DLAMINI QHAMUKILE OCTAVIA',
#   'Single Residential (15)',
#   'Residential',
#   '160,000',
#   191),
#  ('77534084',
#   'ERF 558 of SYDENHAM',
#   '14 PASTORAL ROAD, SYDENHAM',
#   'RAMNANDAN RAKESH',
#   'Single Residential (15)',
#   'Residential',
#   '1,230,000',
#   236),
#  ('58153497',
#   'ERF 1100 of BONELA EXT 12',
#   '4 FORFAR PLACE, BONELA',
#   'PATHER KISTAMMA',
#   'Single Residential (15)',
#   'Residential',
#   '700,000',
#   489),
#  ('20047534',
#   'ERF 490 of COEDMORE',
#   '49 PIGEON DRIVE, YELLOWWOOD PARK',
#   'MOODLEY VIMELA',
#   'Single Residential (15)',
#   'Residential',
#   '1,270,000',
#   1088),
#  ('82831534',
#   'Portion 37 of ERF 777 of DUIKER FONTEIN',
#   '45 CANBERRA AVENUE, PARKHILL',
#   'MBATHA FREDERICK AUSTIN MTHANDENI',
#   'Single Residential (15)',
#   'Residential',
#   '1,060,000',
#   1050),
#  ('96253451',
#   'REM of ERF 2240 of HILLCREST',
#   'INANDA ROAD, HILLCREST',
#   'COTSWOLD DOWNS DEV CO PTY LTD',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '33,000',
#   112053),
#  ('53408850',
#   'ERF 1088 of NTUZUMA H',
#   '11 MVUTHWAMINI LANE, NTUZUMA - H',
#   'LUKHELE BUSISIWE JULIA',
#   'Single Residential (15)',
#   'Residential',
#   '150,000',
#   214),
#  ('53409658',
#   'ERF 1075 of NTUZUMA H',
#   '47 MANANTSHI AVENUE, NTUZUMA - H',
#   'NDABA NOMPUMELELO',
#   'Single Residential (15)',
#   'Residential',
#   '270,000',
#   520),
#  ('53410465',
#   'ERF 1062 of NTUZUMA H',
#   '23 MANANTSHI AVENUE, NTUZUMA - H',
#   'MAPHUMULO BHEKUYISE MATHEWS',
#   'Single Residential (15)',
#   'Residential',
#   '150,000',
#   650),
#  ('53411374',
#   'ERF 43 of DUBE VILLAGE',
#   'DUBE VILLAGE, DUBE VILLAGE',
#   'DUBE JAMES SIPHO',
#   'Single Residential (15)',
#   'Residential',
#   '1,560,000',
#   4191),
#  ('96545343',
#   'Portion 3 of ERF 553 of ASHLEY EXT B',
#   '1A MORRISON ROAD, PINETOWN',
#   'RAMCHURAN DHEEPAK',
#   'Single Residential (15)',
#   'Residential',
#   '970,000',
#   900),
#  ('43534179',
#   'ERF 2354 of SHALLCROSS EXT 2',
#   '279 ALPINE DRIVE, SHALLCROSS',
#   'GIRRAJ NIRAMALA',
#   'Single Residential (15)',
#   'Residential',
#   '770,000',
#   1120),
#  ('65341291',
#   'ERF 386 of KWADABEKA D',
#   '6 200648 STREET, KWADABEKA-D',
#   'NDAWONDE THOMBANA CONSTANCE',
#   'Single Residential (15)',
#   'Residential',
#   '200,000',
#   300),
#  ('65349271',
#   'ERF 396 of KWADABEKA D',
#   '5 200649 STREET, KWADABEKA-D',
#   'NKABINDE BUTINI JOHAN',
#   'Single Residential (15)',
#   'Residential',
#   '140,000',
#   300),
#  ('25348017',
#   'Portion 609 of ERF 978 of FARM WATERFALL NO. 978',
#   '21 MAC MAC DRIVE, WATERFALL',
#   'COLEMAN DAVID GARTH',
#   'Single Residential (15)',
#   'Residential',
#   '1,290,000',
#   1872),
#  ('35340144',
#   'ERF 1610 of FOLWENI B',
#   '4 VUMANDABA STREET, FOLWENI-B',
#   'KHAMBULE ZIFIKILE SIBUSISIWE',
#   'Single Residential (15)',
#   'Residential',
#   '110,000',
#   208),
#  ('54534184',
#   'ERF 3718 of LOVU',
#   '3 10156 STREET, LOVU',
#   'MAKHANYA PATIENCE NOZIPHO',
#   'Single Residential (15)',
#   'Residential',
#   '630,000',
#   390),
#  ('61534193',
#   'ERF 7771 of VERULAM EXT 52',
#   '125 HEATHROW AVENUE, PARKGATE',
#   'MADASAMY NALINI',
#   'Single Residential (15)',
#   'Residential',
#   '480,000',
#   375),
#  ('51353489',
#   'Portion 1514 of ERF 1575 of COTTON LANDS NO. 1575',
#   ', INANDA NU',
#   'SIJAKO LUCRETIA NONTOBEKO',
#   'Single Residential (15)',
#   'Residential',
#   '210,000',
#   20234),
#  ('60534193',
#   'ERF 1214 of UMLAZI BB',
#   '25 NANDI ROAD, UMLAZI-BB',
#   'KUMALO ADELAIDE',
#   'Single Residential (15)',
#   'Residential',
#   '870,000',
#   414),
#  ('60467534',
#   'ERF 533 of UMLAZI',
#   '23 MBOPHA CIRCLE, UMLAZI-BB',
#   'MBUTHO FAYEDWA SIMON',
#   'Single Residential (15)',
#   'Residential',
#   '270,000',
#   535),
#  ('31865347',
#   'ERF 1688 of INANDA F',
#   '14 108789 STREET, AMATIKWE',
#   'REGIONAL & LAND AFFAIRS',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '37,000',
#   300),
#  ('30106534',
#   'ERF 1168 of NTUZUMA A',
#   '48 DLAMAHLAHLA STREET, NTUZUMA-A',
#   'SHANGASE SIFISO MAXWELL',
#   'Single Residential (15)',
#   'Residential',
#   '280,000',
#   491),
#  ('73853447',
#   'Portion 3991 of ERF 107 of CHATSWORTH',
#   '64 741 ROAD, RISECLIFF',
#   'JAIKARUN SHAMAIN ANKOOR',
#   'Single Residential (15)',
#   'Residential',
#   '590,000',
#   209),
#  ('83053432',
#   'Portion 340 of ERF 6 of DUIKER FONTEIN',
#   '11 BARWOOD PLACE, KENVILLE',
#   'REDDY KUBERAN',
#   'Single Residential (15)',
#   'Residential',
#   '1,000,000',
#   526),
#  ('41534048',
#   'Portion 43 of ERF 798 of SEA VIEW',
#   '74 SHARP PLACE, MONTCLAIR',
#   'MSWELI XOLANI-PETROS VERNON',
#   'Single Residential (15)',
#   'Residential',
#   '840,000',
#   1457),
#  ('43745342',
#   'ERF 253 of CARRINGTON HEIGHTS',
#   '53 GRUNDEL ROAD, GLENMORE',
#   'MILEHAM HENRICA BIANCA',
#   'Single Residential (15)',
#   'Residential',
#   '1,200,000',
#   786),
#  ('20513534',
#   'ERF 567 of CLAYFIELD',
#   '32 MILLCLAY CLOSE, CLAYFIELD',
#   'GOUNDEN PUSHPA',
#   'Single Residential (15)',
#   'Residential',
#   '680,000',
#   200),
#  ('89534096',
#   'ERF 2037 of DURBAN NORTH',
#   '64 BALMORAL DRIVE, BROADWAY',
#   'WALTER STEPHEN PATRICK',
#   'Single Residential (15)',
#   'Residential',
#   '3,380,000',
#   1398),
#  ('05534334',
#   'ERF 1940 of CRAIGIEBURN EXT 15',
#   '36 300024 STREET, CRAIGIEBURN',
#   'ETHEKWINI MUNICIPALITY',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '38,000',
#   327),
#  ('05545343',
#   'ERF 1808 of CRAIGIEBURN EXT 15',
#   'PAMBATE ROAD, CRAIGIEBURN',
#   'ETHEKWINI MUNICIPALITY',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '18,000',
#   301),
#  ('53400971',
#   'ERF 1314 of NTUZUMA H',
#   '10 NDABAZABANTU LANE, NTUZUMA - H',
#   'SHOZI WINI WINEFRIEDAH',
#   'Single Residential (15)',
#   'Residential',
#   '210,000',
#   275),
#  ('53401779',
#   'ERF 1296 of NTUZUMA H',
#   '103 ITHAMBO WALK, NTUZUMA - H',
#   'NDIMANDE RICHMAN NDODO',
#   'Single Residential (15)',
#   'Residential',
#   '210,000',
#   260),
#  ('53402587',
#   'ERF 1274 of NTUZUMA H',
#   '30 BUHLEBESIZWE LANE, NTUZUMA - H',
#   'ZUNGU THOLAKELE PRICILLA',
#   'Single Residential (15)',
#   'Residential',
#   '200,000',
#   256),
#  ('53403294',
#   'ERF 1263 of NTUZUMA H',
#   '9 110100 STREET, NTUZUMA - H',
#   'ZUMA MZIBENI JOHN',
#   'Single Residential (15)',
#   'Residential',
#   '250,000',
#   270),
#  ('53404709',
#   'ERF 1237 of NTUZUMA H',
#   '21 110099 STREET, NTUZUMA - H',
#   'DLOMO BONGEKILE EUNICE',
#   'Single Residential (15)',
#   'Residential',
#   '210,000',
#   295),
#  ('53405517',
#   'ERF 1218 of NTUZUMA H',
#   '10 110099 STREET, NTUZUMA - H',
#   'DLOMO NOKUTHULA MILDRED',
#   'Single Residential (15)',
#   'Residential',
#   '270,000',
#   233),
#  ('53406426',
#   'ERF 1099 of NTUZUMA H',
#   '14 UMFISANE LANE, NTUZUMA - H',
#   'LUTHULI JABUISIWE GLADYS',
#   'Single Residential (15)',
#   'Residential',
#   '150,000',
#   273),
#  ('53407234',
#   'ERF 1091 of NTUZUMA H',
#   '19 MVUTHWAMINI LANE, NTUZUMA - H',
#   'SHEZI WALTER MONWABISI',
#   'Single Residential (15)',
#   'Residential',
#   '280,000',
#   343),
#  ('53407941',
#   'ERF 1119 of NTUZUMA H',
#   '17 UMFISANE LANE, NTUZUMA - H',
#   'MAJOLA NONHLANHLA YVONNE',
#   'Single Residential (15)',
#   'Residential',
#   '150,000',
#   358),
#  ('96505347',
#   'ERF 25255 of PINETOWN',
#   '4 200041 STREET, SITHUNDU HILLS',
#   'HADEBE RONALD',
#   'Single Residential (15)',
#   'Residential',
#   '180,000',
#   359),
#  ('96534031',
#   'ERF 1066 of EKUPHUMELELENI i',
#   '5 UMFOLOZI PLACE, Ekuphumeleleni',
#   'MTTHETHWA RAPHAEL THULANI',
#   'Single Residential (15)',
#   'Residential',
#   '210,000',
#   370),
#  ('97183534',
#   'Portion 30 of ERF 692 of BRICKFIELD',
#   '122 RAMSEY AVENUE, DURBAN',
#   'ETHEKWINI MUNICIPALITY',
#   'Roads (50)',
#   'PSI',
#   '1,000',
#   669),
#  ('25534161',
#   'ERF 705 of QUEENSBURGH',
#   '525 STELLA ROAD, MALVERN',
#   'NAIDU VIJANTHAMMALL',
#   'Single Residential (15)',
#   'Residential',
#   '1,320,000',
#   1350),
#  ('45340057',
#   'ERF 781 of MPUMALANGA B',
#   '9 NONDABA ROAD, MPUMALANGA-B',
#   'THUSI ZIFO PHILEMON',
#   'Single Residential (15)',
#   'Residential',
#   '470,000',
#   325),
#  ('58534192',
#   'Portion 323 of ERF 907 of STERKSPRUIT NO. 907',
#   '323/9, DRUMMOND',
#   'MOSTERT JOHANNES SIMON',
#   'Single Residential (15)',
#   'Residential',
#   '1,790,000',
#   81553),
#  ('05534137',
#   'ERF 19 of HAMBANATI',
#   '31A UMGUNGUNDLOVU ROAD, HAMBANATI VILLAGE',
#   'MANLALELA JOHN',
#   'Single Residential (15)',
#   'Residential',
#   '360,000',
#   256),
#  ('35346106',
#   'ERF 854 of UMHLANGA ROCKS EXT 9',
#   '2 SYLVAN CLOSE, UMHLANGA',
#   'GOVENDER SHOLEN',
#   'Single Residential (15)',
#   'Residential',
#   '4,550,000',
#   1317),
#  ('15534142',
#   'ERF 2416 of CRAIGIEBURN',
#   '30 KHAYA ROAD, CRAIGIEBURN',
#   'NAIDOO SIVAGAMIE',
#   'Single Residential (15)',
#   'Residential',
#   '140,000',
#   264),
#  ('15534950',
#   'ERF 2424 of CRAIGIEBURN',
#   '35 KHAYA ROAD, CRAIGIEBURN',
#   'MNGUNI NKANYISO SELBY',
#   'Single Residential (15)',
#   'Residential',
#   '140,000',
#   268),
#  ('60053419',
#   'ERF 535 of NHLUNGWANE',
#   '50 108501 STREET, NHLUNGWANE',
#   'PITSO ELIZABETH',
#   'Single Residential (15)',
#   'Residential',
#   '110,000',
#   280),
#  ('25169534',
#   'ERF 344 of FOREST HAVEN',
#   '54 SWALLOWHAVEN ROAD, FOREST HAVEN',
#   'BHOODHU NAVAMALLI',
#   'Single Residential (15)',
#   'Residential',
#   '730,000',
#   402),
#  ('02534827',
#   'ERF 318 of ROCKFORD',
#   '14 3RD CRESCENT, ROCKFORD',
#   'PATHER MAGALINGAM',
#   'Single Residential (15)',
#   'Residential',
#   '620,000',
#   333),
#  ('36534043',
#   'ERF 664 of DUNNS GRANT',
#   '230 PINE ROAD, CLAIRWOOD',
#   'SURAJPAL LESLIE',
#   'Unauthorised/ Abandoned/ Illegal Usage (63)',
#   'Unauthorised or Illegal Development/Use',
#   '260,000',
#   697),
#  ('62184534',
#   'ERF 47 of UMLAZI P',
#   '66 ZWELETHU ROAD, UMLAZI-P',
#   'T W CELE',
#   'Single Residential (15)',
#   'Residential',
#   '200,000',
#   348),
#  ('44534253',
#   'REM of Portion 2 of ERF 335 of SEA VIEW',
#   'BRAESIDE ROAD                   , SEA VIEW',
#   'GEM ONT RAAD-COM DEV BOARD',
#   'Roads (50)',
#   'PSI',
#   '1,000',
#   130),
#  ('50589534',
#   'ERF 258 of KWAMASHU E',
#   '91 MNYAYIZA ROAD, KWAMASHU-E',
#   'NDAWONDE NTOMBENHLE JUDITH',
#   'Single Residential (15)',
#   'Residential',
#   '240,000',
#   259),
#  ('40439534',
#   'ERF 3405 of KWAMAKHUTHA A',
#   '9 SPHIWE MKHIZE PLACE, KWAMAKHUTA',
#   'MCINEKA MBUSISO ERIC',
#   'Single Residential (15)',
#   'Residential',
#   '330,000',
#   301),
#  ('10635342',
#   'ERF 11767 of LOVU',
#   '21 500006 STREET, ILLOVU',
#   'THABETHE CONFERENCE DUMISILE',
#   'Single Residential (15)',
#   'Residential',
#   '130,000',
#   228),
#  ('96130534',
#   'ERF 2405 of HILLCREST',
#   'DEERHURST WAY, WATERFALL',
#   'BURN LAWRENCE',
#   'Single Residential (15)',
#   'Residential',
#   '2,810,000',
#   964),
#  ('53411778',
#   'ERF 2297 of NTUZUMA H',
#   '64 IBHU ROAD, NTUZUMA-H',
#   'MEMELA NOTHANDO SURPRISE',
#   'Single Residential (15)',
#   'Residential',
#   '150,000',
#   301),
#  ('96565341',
#   'ERF 291 of PHUMPHELE',
#   '5 SILO AVENUE, PHUMPHELE',
#   'MKIZE ZIBUYILE SALVATORIS ZIWINILE DAPHNE',
#   'Single Residential (15)',
#   'Residential',
#   '440,000',
#   499),
#  ('17534052',
#   'ERF 7146 of PINETOWN EXT 67',
#   '64 PEGASUS ROAD, MARIANHEIGHTS',
#   'MTHEMBU NHLANHLA',
#   'Single Residential (15)',
#   'Residential',
#   '540,000',
#   586),
#  ('25343170',
#   'ERF 339 of MALVERN EXT 6',
#   '85 FAIRLIGHT ROAD, MALVERN',
#   'PILLAY VISHNU',
#   'Single Residential (15)',
#   'Residential',
#   '1,430,000',
#   941),
#  ('15346087',
#   'ERF 702 of GILLITTS',
#   '1 VIRGINIA BOULEVARD, CHELMSFORDVILLE',
#   'LYLE HAZEL EDNA VACY-',
#   'Single Residential (15)',
#   'Residential',
#   '3,160,000',
#   1258),
#  ('31534161',
#   'ERF 1697 of FOLWENI A',
#   '3 510129 STREET, FOLWENI-A',
#   'ETHEKWINI MUNICIPALITY',
#   'Single Residential (15)',
#   'Residential',
#   '120,000',
#   256),
#  ('55534185',
#   'ERF 10209 of LOVU',
#   '70 10454 STREET, ILLOVU',
#   'SABELA OCTAVIA',
#   'Single Residential (15)',
#   'Residential',
#   '130,000',
#   337),
#  ('25340136',
#   'ERF 2937 of TONGAAT EXT 25',
#   '5 NADERI ROAD, FLAMINGO HEIGHTS',
#   'GADDIAH THREEMANADHI',
#   'Single Residential (15)',
#   'Residential',
#   '620,000',
#   317),
#  ('42534174',
#   'ERF 112 of WATERLOO',
#   '8 TURKEY ROAD, WATERLOO',
#   'MTHEMBU SIBONGILE BAPHNEY',
#   'Single Residential (15)',
#   'Residential',
#   '200,000',
#   194),
#  ('63753467',
#   'ERF 178 of UMLAZI J',
#   '162 ZIHLAHLA ROAD, UMLAZI-J',
#   'CIBANE BONGA SHADRACK',
#   'Single Residential (15)',
#   'Residential',
#   '200,000',
#   409),
#  ('60063534',
#   'ERF 670 of UMLAZI AA',
#   'BHEKITHEMBA GROVE, UMLAZI-AA',
#   'NZAMA MUZI WAKITHI CHRISTOPHER',
#   'Single Residential (15)',
#   'Residential',
#   '340,000',
#   552),
#  ('52053428',
#   'ERF 1935 of KWAMASHU Q',
#   '10 108160 STREET, KWAMASHU-Q',
#   'NDLOVU SIPHO PATRICK',
#   'Single Residential (15)',
#   'Residential',
#   '110,000',
#   197),
#  ('50534791',
#   'ERF 1795 of KWAMASHU D',
#   '33 FOREST RING CIRCLE, KWAMASHU-D',
#   'MSIMANGO MAKHOSAZANA WINNIE',
#   'Single Residential (15)',
#   'Residential',
#   '920,000',
#   495),
#  ('31534067',
#   'ERF 367 of INANDA B',
#   '5 SHUKUMA CLOSE, INANDA-B',
#   'MHLONGO FUNGANI GLADYS',
#   'Single Residential (15)',
#   'Residential',
#   '250,000',
#   567),
#  ('31534875',
#   'ERF 375 of INANDA B',
#   '14 SHUKUMA CLOSE, INANDA-B',
#   'KUNENE BUSISIWE WINNIE',
#   'Single Residential (15)',
#   'Residential',
#   '350,000',
#   501),
#  ('40319534',
#   'Portion 149 of ERF 437 of ZEEKOE VALLEI',
#   '59 CONGER PLACE, NEWLANDS EAST',
#   'RASSIE SHELLEY',
#   'Single Residential (15)',
#   'Residential',
#   '1,000,000',
#   305),
#  ('21534240',
#   'ERF 888 of LONGCROFT',
#   '33 UPPERCROFT ROAD, LONGCROFT',
#   'GOVENDER SUSCILLA DEVI',
#   'Single Residential (15)',
#   'Residential',
#   '810,000',
#   200),
#  ('70534082',
#   'Portion 5340 of ERF 107 of CHATSWORTH',
#   '63 KNOCKWATCH AVENUE, MOORTON',
#   'CHAKANA SUSHILA',
#   'Single Residential (15)',
#   'Residential',
#   '480,000',
#   209),
#  ('95340586',
#   'ERF 705 of GLENASHLEY',
#   '10 DOREEN CRESCENT, GLENASHLEY',
#   'MHLANGA KENNEDY',
#   'Single Residential (15)',
#   'Residential',
#   '3,380,000',
#   1012),
#  ('95345536',
#   'ERF 715 of GLENASHLEY',
#   '16 MARION AVENUE, GLENASHLEY',
#   'CONRADIE JOHANNES LODEWIKUS',
#   'Single Residential (15)',
#   'Residential',
#   '4,140,000',
#   1012),
#  ('93265340',
#   'REM of Portion 14 of ERF 161 of ZEEKOE VALLEI',
#   'PETER ROAD                      , PETER ROAD',
#   'SOUTH AFRICAN RAIL COMMUTER CORP LTD',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '320,000',
#   552),
#  ('64534071',
#   'Portion 32 of ERF 651 of BRICKFIELD',
#   '29 CREST WALK, WESTRIDGE',
#   'ETHEKWINI MUNICIPALITY',
#   'Single Residential (15)',
#   'Residential',
#   '400,000',
#   3770),
#  ('14100534',
#   'Portion 187 of ERF 102 of CHATSWORTH',
#   '298 POWERLINE STREET, WESTCLIFF',
#   'GOVENDER DHRUGAMAH',
#   'Single Residential (15)',
#   'Residential',
#   '490,000',
#   186),
#  ('59205340',
#   'ERF 62 of KWADABEKA I',
#   '32 200778 STREET, KWADABEKA-I',
#   'MBHELE NONHLANHLA GOODNESS',
#   'Single Residential (15)',
#   'Residential',
#   '81,000',
#   231),
#  ('53412586',
#   'ERF 1578 of NTUZUMA H',
#   '12 MACIMEZA AVENUE, NTUZUMA - H',
#   'DLOMO BOY DERRICK',
#   'Single Residential (15)',
#   'Residential',
#   '350,000',
#   258),
#  ('96554534',
#   'ERF 921 of EKUPHUMELELENI i',
#   '11 MASINGANA CRESCENT, SAVANNAH PARK',
#   'MNGADI JANETH BUSISIWE',
#   'Single Residential (15)',
#   'Residential',
#   '200,000',
#   497),
#  ('68534104',
#   'ERF 5549 of KWANDENGEZI A',
#   '33 LAMULA ROAD, KWANDENGEZI-A',
#   'KWAZULU HOUSING CO (PTY) LTD',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '50,000',
#   465),
#  ('35342168',
#   'ERF 428 of MPUMALANGA C',
#   '69 MAPHUMULO ROAD, MPUMALANGA-C',
#   'KZNPA',
#   'Single Residential (15)',
#   'Residential',
#   '130,000',
#   350),
#  ('28534158',
#   'ERF 69 of FOLWENI A',
#   '13 510091 STREET, FOLWENI-A',
#   'M J MKHIZE',
#   'Single Residential (15)',
#   'Residential',
#   '110,000',
#   212),
#  ('26534158',
#   'ERF 72 of LA MERCY',
#   '6 EDEN ROSE WALK, LA MERCY',
#   'HEMRAJH SUBASHNI',
#   'Single Residential (15)',
#   'Residential',
#   '3,020,000',
#   2071),
#  ('63534195',
#   'ERF 196 of EVEREST HEIGHTS',
#   '54 OLIVINE ROAD, EVEREST HEIGHTS',
#   'THE DR SL BISRAM FAMILY TRUST',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '370,000',
#   1508),
#  ('50509534',
#   'Portion 4 of ERF 2619 of CLIFTON No. 2619',
#   ', KWANTAMNTENGAYO',
#   'INGONYAMA TRUST-TRUSTEES',
#   'Single Residential (15)',
#   'Residential',
#   '1,150,000',
#   101173),
#  ('62534195',
#   'ERF 2131 of UMLAZI Q',
#   '33 107994 STREET, UMLAZI-Q',
#   'KWAZULU GOVERNMENT',
#   'Single Residential (15)',
#   'Residential',
#   '190,000',
#   221),
#  ('62534903',
#   'ERF 2139 of UMLAZI Q',
#   '49 107994 STREET, UMLAZI-Q',
#   'MUNGWE NTOMBIFUTHI WINNIE',
#   'Single Residential (15)',
#   'Residential',
#   '170,000',
#   243),
#  ('60669534',
#   'ERF 865 of UMLAZI C',
#   '138 BABAKHULU AVENUE, UMLAZI-C',
#   'MTHEMBU KILONI',
#   'Single Residential (15)',
#   'Residential',
#   '1,150,000',
#   364),
#  ('50983534',
#   'ERF 1462 of KWAMASHU G',
#   '1 NKABINDE ROAD, KWAMASHU-G',
#   'KWAZULU GOVERNMENT',
#   'Single Residential (15)',
#   'Residential',
#   '620,000',
#   523),
#  ('51126534',
#   'ERF 1266 of BROOKDALE',
#   '37 WATTLEBROOK CRESCENT, BROOKDALE',
#   'NADASEN VIJAYLUXMIE',
#   'Single Residential (15)',
#   'Residential',
#   '680,000',
#   505),
#  ('20534239',
#   'ERF 738 of CLAYFIELD',
#   '88 ROSECLAY PLACE, CLAYFIELD',
#   'PETERS EVELYN HILDA B-E',
#   'Single Residential (15)',
#   'Residential',
#   '640,000',
#   292),
#  ('64105534',
#   'Portion 1055 of ERF 300 of CHATSWORTH',
#   '41 SEAFERN ROAD, CROSSMOOR',
#   'RAMSAROOP AMITH',
#   'Single Residential (15)',
#   'Residential',
#   '690,000',
#   209),
#  ('90534097',
#   'ERF 1 of AVOCA',
#   '19 TYNE AVENUE, AVOCA',
#   'SHINGA THULANI PETROS',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '310,000',
#   910),
#  ('05344031',
#   'ERF 3117 of DURBAN',
#   '39 AVONDALE ROAD, ESSENWOOD',
#   'NAICKER KEVIN',
#   'Single Residential (15)',
#   'Residential',
#   '1,780,000',
#   417),
#  ('68095534',
#   'REM of ERF 4418 of RESERVOIR HILLS',
#   '79 MEMBREY ROAD                    , PALMIET',
#   'NAIR MEENATCHIE SHUNMUGAM',
#   'Single Residential (15)',
#   'Residential',
#   '980,000',
#   6008),
#  ('70761534',
#   'REM of Portion 8401 of ERF 107 of CHATSWORTH',
#   '1 KAPOTA STREET, ARENA PARK',
#   'THE RIVERSTONE TRUST-TRUSTEES',
#   'Single Residential (15)',
#   'Residential',
#   '820,000',
#   662),
#  ('00667534',
#   'REM of Portion 849 of ERF 85 of CHATSWORTH',
#   '131 RIVERSDALE ROAD, SILVERGLEN',
#   'BAIJNATH GUMBHEER',
#   'Single Residential (15)',
#   'Residential',
#   '790,000',
#   638),
#  ('27006534',
#   'Portion 2 of ERF 16946 of ILLOVO NO 16946',
#   'UNKNOWN, ILLOVU',
#   'ETHEKWINI MUNICIPALITY',
#   'Homes (Nursing etc) (20)',
#   'Business & Commercial',
#   '24,080,000',
#   25614),
#  ('64025340',
#   'Portion 253 of ERF 300 of CHATSWORTH',
#   '42 SAGEBRUSH ROAD, CROSSMOOR',
#   'MOODLEY LOGANATHAN',
#   'Single Residential (15)',
#   'Residential',
#   '620,000',
#   296),
#  ('20053469',
#   'ERF 620 of AUSTERVILLE',
#   '47 ENGELBRECHT ROAD, AUSTERVILLE',
#   'TWICE MATHEW',
#   'Single Residential (15)',
#   'Residential',
#   '630,000',
#   324),
#  ('53472046',
#   'ERF 1507 OF LOT 10',
#   '301 VUSI MZIMELA ROAD, WESTRIDGE',
#   'COMMUNITY DEVELOPMENT BOARD',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '1,350,000',
#   2023),
#  ('95346041',
#   'ERF 716 of GLENASHLEY',
#   '14 MARION AVENUE, GLENASHLEY',
#   'MTHIYANE NHLANHLA ALEXANDER',
#   'Single Residential (15)',
#   'Residential',
#   '3,860,000',
#   1012),
#  ('63195342',
#   'ERF 1461 of UMLAZI V',
#   '230 107790 STREET, UMLAZI-V',
#   'KWAZULU GOVERNMENT',
#   'Single Residential (15)',
#   'Residential',
#   '360,000',
#   319),
#  ('08953472',
#   'Portion 1826 of ERF 104 of CHATSWORTH',
#   '45 HARLEY STREET, HAVENSIDE',
#   'GOVENDER THYSAN',
#   'Single Residential (15)',
#   'Residential',
#   '610,000',
#   344),
#  ('51488534',
#   'ERF 135 of MINITOWN',
#   '33 400124 STREET, MINITOWN',
#   'ZONDI NTOMBEMHLOPHE WEZIWE',
#   'Single Residential (15)',
#   'Residential',
#   '180,000',
#   461),
#  ('53413495',
#   'ERF 1932 of NTUZUMA C',
#   '1 106586 STREET, NTUZUMA - C',
#   'ETHEKWINI MUNICIPALITY',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '250,000',
#   3048),
#  ('45340160',
#   'ERF 2926 of SHALLCROSS EXT 5',
#   '100 SAFFRON DRIVE, NORTHDENE',
#   'DHOOKOO KOGILA',
#   'Single Residential (15)',
#   'Residential',
#   '810,000',
#   358),
#  ('40534176',
#   'ERF 1088 of SHALLCROSS',
#   '39 PYRENEES STREET, SHALLCROSS',
#   'HARIBOL 108 FAMILY TRUST-TRUSTEES',
#   'Single Residential (15)',
#   'Residential',
#   '490,000',
#   297),
#  ('25348120',
#   'ERF 2960 of QUEENSBURGH EXT 12',
#   '36 BYRNE CRESCENT, QUEENSBURGH',
#   'NEL THERESA MAGRIETA',
#   'Single Residential (15)',
#   'Residential',
#   '2,020,000',
#   1000),
#  ('09534044',
#   'Portion 12 of ERF 6582 of PINETOWN',
#   '20 FERN AVENUE, REGENCY PARK',
#   'BUTHELEZI WILLIAM ANANIA',
#   'Single Residential (15)',
#   'Residential',
#   '610,000',
#   1287),
#  ('05346073',
#   'Portion 9 of ERF 86 of AMANZIMTOTI',
#   '144 LEWIS DRIVE, AMANZIMTOTI',
#   'MANKAHLA NOMBEKO',
#   'Single Residential (15)',
#   'Residential',
#   '1,590,000',
#   1695),
#  ('40534170',
#   'ERF 74 of KWAMAKHUTHA A',
#   '9 MPHOSWA AVENUE, KWAMAKHUTA',
#   'KHUBISA MZOMUSHA VICTOR',
#   'Single Residential (15)',
#   'Residential',
#   '330,000',
#   375),
#  ('09534141',
#   'ERF 321 of MOUNT EDGECOMBE EXT 3',
#   '3 SILVER OAK AVENUE, MOUNT EDGECOMBE ESTATE',
#   "CHETTY'S TYRE BREAKDOWN SERVICE CC",
#   'Single Residential (15)',
#   'Residential',
#   '2,570,000',
#   1054),
#  ('38534170',
#   'ERF 2112 of UMHLANGA ROCKS EXT 18',
#   '51 MIDSOMER CRESCENT, SOMERSET PARK',
#   'PANDAY VICKEY JAIRAJ',
#   'Single Residential (15)',
#   'Residential',
#   '6,100,000',
#   1734),
#  ('62853456',
#   'ERF 683 of UMLAZI T',
#   '201 1603 STREET, UMLAZI-T',
#   'KWAZULU GOVERNMENT',
#   'Single Residential (15)',
#   'Residential',
#   '190,000',
#   475),
#  ('50286534',
#   'ERF 1334 of KWAMASHU C',
#   '28 USUTHU ROAD, KWAMASHU-C',
#   'MHLANZI HAMILTON',
#   'Single Residential (15)',
#   'Residential',
#   '220,000',
#   263),
#  ('31253489',
#   'ERF 332 of INANDA A',
#   '132 SANDLWANA DRIVE, INANDA-A',
#   'THANDIWE PHLOMENI ZONDI',
#   'Single Residential (15)',
#   'Residential',
#   '270,000',
#   573),
#  ('21253460',
#   'ERF 312 of WESTHAM',
#   '282 FERNHAM DRIVE, WESTHAM',
#   'GQALA NONZUZO AGNES',
#   'Single Residential (15)',
#   'Residential',
#   '600,000',
#   205),
#  ('73534994',
#   'Portion 1803 of ERF 101 of CHATSWORTH',
#   '165 EQUALITY AVENUE, CROFTDENE',
#   'PILLAY DEVAGIE',
#   'Single Residential (15)',
#   'Residential',
#   '510,000',
#   341),
#  ('75342081',
#   'Portion 94 of ERF 328 of SPRINGFIELD',
#   '50 CEDARVILLE ROAD, CLARE HILLS',
#   'GOVENDER THILLANAYAGEE',
#   'Single Residential (15)',
#   'Residential',
#   '940,000',
#   945),
#  ('26372534',
#   'ERF 158 of MEREWENT',
#   '9 SALSEETE ROAD, MEREWENT',
#   'GOUNDER VADIVALOO B-E',
#   'Single Residential (15)',
#   'Residential',
#   '520,000',
#   391),
#  ('26534336',
#   'ERF 1921 of MEREWENT',
#   '18 TEZPUR PLACE, MEREWENT',
#   'SIMON GINO',
#   'Single Residential (15)',
#   'Residential',
#   '520,000',
#   243),
#  ('26553425',
#   'ERF 1795 of MEREWENT',
#   '46 INDORE ROAD, MEREWENT',
#   'NAIDOO CHARLENE',
#   'Single Residential (15)',
#   'Residential',
#   '510,000',
#   244),
#  ('73534893',
#   'Portion 180 of ERF 101 of CHATSWORTH',
#   '163 EQUALITY AVENUE, CROFTDENE',
#   'NELSON SALATCHI',
#   'Single Residential (15)',
#   'Residential',
#   '450,000',
#   240),
#  ('31053480',
#   'Portion 94 of ERF 236 of BELLAIR',
#   '27 WRENFORD PLACE, MOUNT VERNON',
#   'KUPPAN ADRIAN',
#   'Single Residential (15)',
#   'Residential',
#   '790,000',
#   684),
#  ('00190534',
#   'ERF 30781 of PINETOWN',
#   '16 MAHOGANY ROAD, MAHOGANY RIDGE',
#   'ZEDEK TRADING 656 PROPRIETARY LIMITED',
#   'Industrial (45)',
#   'Industrial',
#   '60,760,000',
#   22702),
#  ('96753499',
#   'ERF 1122 of MZOMUHLE',
#   '124 TOTTENHAM ROAD, VERULAM',
#   'MTYALI ZENELISA',
#   'Single Residential (15)',
#   'Residential',
#   '140,000',
#   360),
#  ('55347140',
#   'Portion 44 of ERF 4632 of RESERVOIR HILLS',
#   '84 PLUMSTEAD CRESCENT, RESERVOIR HILLS',
#   'GOVENDER SELVARANI',
#   'Single Residential (15)',
#   'Residential',
#   '860,000',
#   957),
#  ('04534037',
#   'ERF 2303 of KLOOF EXT 11',
#   '36 CHERRY ROAD, MOTALABAD',
#   'DINGA SIPHO',
#   'Single Residential (15)',
#   'Residential',
#   '930,000',
#   867),
#  ('00053475',
#   'ERF 4877 of KLOOF',
#   '14 FLOWER LANE, WYEBANK',
#   'SITHOLE KHETHIWE GOODNESS',
#   'Single Residential (15)',
#   'Residential',
#   '140,000',
#   453),
#  ('15348104',
#   'ERF 4002 of ISIPINGO EXT 33',
#   '4 FIGTREE PLACE, ISIPINGO HILLS',
#   'ROYEPPEN AMICA MARCELLE ROSA',
#   'Single Residential (15)',
#   'Residential',
#   '740,000',
#   446),
#  ('65344114',
#   'ERF 416 of MAGABENI A',
#   '84 SIDIYA HIGHWAY, MAGABHENI-A',
#   'NDLOVU BADABUKILE RONAH',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '47,000',
#   553),
#  ('48534180',
#   'ERF 4205 of WATERLOO EXT 3',
#   '55 20220 STREET, WATERLOO',
#   'MTHEMBU NKULULEKO GODFREY',
#   'Single Residential (15)',
#   'Residential',
#   '98,000',
#   218),
#  ('63165345',
#   'ERF 1108 of UMLAZI V',
#   '20 107341 STREET, UMLAZI-V',
#   'MAGWAZA MFANA GIDEON',
#   'Single Residential (15)',
#   'Residential',
#   '680,000',
#   557),
#  ('61174534',
#   'ERF 466 of UMLAZI G',
#   'SIBUSISO MDAKANE DRIVE, UMLAZI-G',
#   'NDWANDWE NINIZA MZIWOMOYA',
#   'Single Residential (15)',
#   'Residential',
#   '310,000',
#   467),
#  ('51296534',
#   'ERF 581 of KWAMASHU K',
#   '5 MZWILILI ROAD, KWAMASHU-K',
#   'DUBAZANE MZIKAYISE INNOCENT',
#   'Single Residential (15)',
#   'Residential',
#   '340,000',
#   260),
#  ('31153499',
#   'ERF 1200 of NTUZUMA G',
#   '14 SOJABULA ROAD, INANDA-B',
#   'MTSHALI ELIZABETH ZANDILE',
#   'Single Residential (15)',
#   'Residential',
#   '440,000',
#   469),
#  ('33453452',
#   'ERF 1413 of LENHAM',
#   '4 GRENLEN CRESCENT, LENHAM',
#   'ABDOOL RAJUB',
#   'Single Residential (15)',
#   'Residential',
#   '580,000',
#   158),
#  ('20753409',
#   'ERF 863 of REDFERN',
#   '20 CROWFERN CLOSE, REDFERN',
#   'SEWSANKER ROOPNARAIN',
#   'Single Residential (15)',
#   'Residential',
#   '900,000',
#   262),
#  ('73105341',
#   'Portion 1153 of ERF 101 of CHATSWORTH',
#   '222 CRIMBY AVENUE, WESTCLIFF',
#   'GANESH PREMNANDHA',
#   'Single Residential (15)',
#   'Residential',
#   '850,000',
#   186),
#  ('26653415',
#   'Portion 144 of ERF 14836 of CLAIRWENT THREE NO. 14836',
#   '2 MOLTAN PLACE, MEREWENT',
#   'NAIDOO ERISHENI',
#   'Single Residential (15)',
#   'Residential',
#   '770,000',
#   335),
#  ('60653449',
#   'Portion 29 of ERF 809 of BRICKFIELD',
#   '37 ST THERESA ROAD, SPARKS',
#   'GORDON JENNIFER SALOME GLADYS',
#   'Single Residential (15)',
#   'Residential',
#   '920,000',
#   481),
#  ('26575342',
#   'Portion 460 of ERF 105 of WENTWORTH',
#   '58 SILVERTREE ROAD, AUSTERVILLE',
#   'PARKINS MARIE FRANCINA',
#   'Single Residential (15)',
#   'Residential',
#   '600,000',
#   399),
#  ('52035534',
#   'ERF 355 of HILLGROVE',
#   '38 GLADEHILL CRESCENT, HILLGROVE',
#   'HARRI MARSELINO JAMES',
#   'Single Residential (15)',
#   'Residential',
#   '730,000',
#   395),
#  ('50005342',
#   'ERF 45 of SUNNYSIDE PARK',
#   '84168 STREET, ADAMS MISSION',
#   'MHLONGO MZAMO EDWIN',
#   'Single Residential (15)',
#   'Residential',
#   '450,000',
#   475),
#  ('32534371',
#   'ERF 1008 of INANDA G',
#   '120039 STREET, INANDA CONGO',
#   'MSOMI SIBUSISO MESHACK',
#   'Single Residential (15)',
#   'Residential',
#   '72,000',
#   355),
#  ('96090534',
#   'REM of ERF 506 of KINGSBURGH',
#   'UNKNOWN, KINGSBURGH',
#   'SOUTH AFRICAN NATIONAL ROADS AGENCY LTD',
#   'Roads (50)',
#   'PSI',
#   None,
#   3148),
#  ('97053456',
#   'Portion 1 of ERF 34 of RIVERHORSE VALLEY',
#   '24 IMVUBU PARK PLACE, RIVERHORSE VALLEY',
#   'INVESTEC PROPERTY FUND LIMITED',
#   'Industrial (45)',
#   'Industrial',
#   '106,950,000',
#   46282),
#  ('66534102',
#   'ERF 311 of KLAARWATER',
#   '3 MKOMAZI STREET, KLAARWATER',
#   'MAKHUBU REGINA',
#   'Single Residential (15)',
#   'Residential',
#   '120,000',
#   304),
#  ('42534176',
#   'ERF 1051 of MPUMALANGA E',
#   '75 MKHIZE MAIN ROAD, MPUMALANGA-E',
#   'N ZULU',
#   'Single Residential (15)',
#   'Residential',
#   '130,000',
#   259),
#  ('15534145',
#   'REM of ERF 1028 of ISIPINGO',
#   '11 SBU MAGWANYANE DRIVE, LOTUS PARK',
#   'SOUTHERN TRANSITIONAL METROPOLITAN SUBSTRUCTURE COUNCIL',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '800,000',
#   116702),
#  ('53406217',
#   'ERF 2297 of LOVU',
#   '34 10405 STREET, LOVU',
#   'KHANYASE PHUMZILE ELIZABETH',
#   'Single Residential (15)',
#   'Residential',
#   '160,000',
#   328),
#  ('53416216',
#   'ERF 2373 of LOVU',
#   '126 10080 STREET, LOVU',
#   'MSELEKU DUDUZILE ANNAH',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '48,000',
#   205),
#  ('53428134',
#   'ERF 2416 of LOVU',
#   '20 10081 STREET, LOVU',
#   'NDELU MAKAZI FLORENCE',
#   'Single Residential (15)',
#   'Residential',
#   '210,000',
#   322),
#  ('53442172',
#   'ERF 2427 of LOVU',
#   '96 10080 STREET, LOVU',
#   'MAZIBUKO ROSEMARY THOBILE',
#   'Single Residential (15)',
#   'Residential',
#   '160,000',
#   318),
#  ('53454191',
#   'ERF 2452 of LOVU',
#   '12 10086 STREET, LOVU',
#   'DLAMINI FIKILE MIRRIAM',
#   'Single Residential (15)',
#   'Residential',
#   '480,000',
#   300),
#  ('53468130',
#   'ERF 2477 of LOVU',
#   '107 10080 STREET, LOVU',
#   'GUMEDE SIYEZA JAMES',
#   'Single Residential (15)',
#   'Residential',
#   '480,000',
#   205),
#  ('53480148',
#   'ERF 2499 of LOVU',
#   '14 10158 STREET, LOVU',
#   'SABELA NTOMBIKITHI RACHEL',
#   'Single Residential (15)',
#   'Residential',
#   '670,000',
#   312),
#  ('53490349',
#   'ERF 2524 of LOVU',
#   '36 10411 ROAD, LOVU',
#   'SITHOLE CYPRIAN SICELO',
#   'Single Residential (15)',
#   'Residential',
#   '160,000',
#   347),
#  ('53498127',
#   'ERF 2551 of LOVU',
#   '5 10411 ROAD, LOVU',
#   'MBUTHO SIWINILE',
#   'Single Residential (15)',
#   'Residential',
#   '180,000',
#   465),
#  ('53444194',
#   'ERF 1569 of VERULAM EXT 16',
#   '51 JACARANDA AVENUE, MOUNTVIEW',
#   'NAICKER PAT',
#   'Single Residential (15)',
#   'Residential',
#   '460,000',
#   289),
#  ('53460152',
#   'ERF 1577 of VERULAM EXT 16',
#   '67 JACARANDA AVENUE, MOUNTVIEW',
#   'SOOKDEW NIRUPA',
#   'Single Residential (15)',
#   'Residential',
#   '420,000',
#   391),
#  ('53476111',
#   'ERF 1585 of VERULAM EXT 16',
#   '83 JACARANDA AVENUE, MOUNTVIEW',
#   'MKHWANAZI BAJABULILE JOYCE',
#   'Single Residential (15)',
#   'Residential',
#   '420,000',
#   343),
#  ('53488130',
#   'ERF 1591 of VERULAM EXT 16',
#   '40 GREENFIELD WAY, MOUNTVIEW',
#   'PILLAI NOMMIE',
#   'Single Residential (15)',
#   'Residential',
#   '440,000',
#   152),
#  ('65534300',
#   'ERF 343 of MALUKAZI',
#   '24 NKUNDLENI GROVE, MALUKAZI',
#   'BENGU NTOMBIYEDWA',
#   'Single Residential (15)',
#   'Residential',
#   '98,000',
#   250),
#  ('64002534',
#   'ERF 2602 of UMLAZI E',
#   'UMLAZI - E                      , UMLAZI - E',
#   'NZUZA MUNTUKAZIBONI ISAAC',
#   'Single Residential (15)',
#   'Residential',
#   '810,000',
#   377),
#  ('62165344',
#   'ERF 1443 of UMLAZI N',
#   '4 GAZU WALK, UMLAZI-N',
#   'NGUBANE DORIS ZONKE',
#   'Single Residential (15)',
#   'Residential',
#   '610,000',
#   1138),
#  ('62083534',
#   'ERF 510 of UMLAZI N',
#   '10 PHILA NDWANDWE ROAD, UMLAZI-N',
#   'YENI THULISIWE MAGNES',
#   'Single Residential (15)',
#   'Residential',
#   '760,000',
#   914),
#  ('60155343',
#   'ERF 264 of UMLAZI A',
#   '59 VENI YENI ROAD, UMLAZI-A',
#   'SIKAKANE NOMINGONI JOHANNES',
#   'Single Residential (15)',
#   'Residential',
#   '480,000',
#   440),
#  ('50085342',
#   'ERF 705 of KWAMASHU B',
#   '29 CICI ROAD, KWAMASHU-B',
#   'NXUMALO GLADYS FLORAH THANDIWE',
#   'Single Residential (15)',
#   'Residential',
#   '590,000',
#   257),
#  ('50015349',
#   'ERF 5 of KWAMASHU B',
#   '7 UDWENDWE ROAD, KWAMASHU-B',
#   'SIBIYA THALIWE',
#   'Single Residential (15)',
#   'Residential',
#   '380,000',
#   261),
#  ('30915341',
#   'ERF 987 of NTUZUMA F',
#   '26 IPHITHI AVENUE, NTUZUMA-F',
#   'MCHUNU SIMON NKOSENYE',
#   'Single Residential (15)',
#   'Residential',
#   '310,000',
#   410),
#  ('60115534',
#   'ERF 56 of EZIMANGWENI',
#   '86 NTSHANTSHA ROAD, EZIMANGWENI',
#   'LIMAPI TYELINZIMA',
#   'Single Residential (15)',
#   'Residential',
#   '150,000',
#   137),
#  ('53413798',
#   'REM of Portion 11 of ERF 1 of the farm PIEZANG REVIER NO. 805',
#   'PIEZANG RIVIER, PIEZANG RIVIER 805',
#   'PHOENIX SETTLEMENT TRUST',
#   'Public Buildings (81)',
#   'Business & Commercial',
#   '4,660,000',
#   76977),
#  ('53414001',
#   'ERF 2264 of NTUZUMA G',
#   '52 KING BHEKUZULU DRIVE, NTUZUMA - G',
#   'ETHEKWINI MUNICIPALITY',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '210,000',
#   1314),
#  ('15342049',
#   'REM of ERF 2567 of PINETOWN',
#   '33 LANGWOOD ROAD, PINETOWN',
#   'NAIDOO NELENA',
#   'Single Residential (15)',
#   'Residential',
#   '1,530,000',
#   1214),
#  ('33534169',
#   'REM of ERF 2034 of WESTVILLE',
#   '29 KONIGKRAMER AVENUE, BEREA WEST',
#   'NGONELO TANDIWE EUNICE',
#   'Single Residential (15)',
#   'Residential',
#   '1,630,000',
#   2521),
#  ('35343180',
#   'ERF 198 of BEREA WEST',
#   '12 GLENDALE AVENUE, BEREA WEST',
#   'BOTHA RANYA WYLMA',
#   'Single Residential (15)',
#   'Residential',
#   '2,150,000',
#   3514),
#  ('05344059',
#   'ERF 24556 of PINETOWN EXT 141',
#   '41 OLEANDER ROAD, MADIBA VALLEY',
#   'BIYASE ANDILE YVONNE',
#   'Single Residential (15)',
#   'Residential',
#   '80,000',
#   398),
#  ('07534141',
#   'ERF 3087 of KLOOF EXT 17',
#   '4 CROWN EAGLE PLACE, KLOOF',
#   'MZOBE ELIJAH MKHUMBUZI',
#   'Single Residential (15)',
#   'Residential',
#   '1,370,000',
#   2403),
#  ('53410159',
#   'ERF 823 of BOTHAS HILL',
#   '66013 STREET, QUADI SOUTH 2',
#   'MULONGO TERRY THAMSANQA',
#   'Single Residential (15)',
#   'Residential',
#   '63,000',
#   300),
#  ('53426118',
#   'ERF 831 of BOTHAS HILL',
#   '66013 STREET, QUADI SOUTH 2',
#   'MAGWAZA NONHLANHLA SIZENI',
#   'Single Residential (15)',
#   'Residential',
#   '63,000',
#   300),
#  ('53440156',
#   'ERF 839 of BOTHAS HILL',
#   '66013 STREET, QUADI SOUTH 2',
#   'MGENGE FUMBETHENI BONGEKILE',
#   'Single Residential (15)',
#   'Residential',
#   '63,000',
#   300),
#  ('53454195',
#   'ERF 847 of BOTHAS HILL',
#   '66013 STREET, QUADI SOUTH 2',
#   'HLONGWA THOKOZANI',
#   'Single Residential (15)',
#   'Residential',
#   '63,000',
#   300),
#  ('53468134',
#   'ERF 860 of BOTHAS HILL',
#   '66013 STREET, QUADI SOUTH 2',
#   'SHANGE GLORIA BUYISIWE',
#   'Single Residential (15)',
#   'Residential',
#   '63,000',
#   300),
#  ('53482273',
#   'ERF 868 of BOTHAS HILL',
#   '66013 STREET, QUADI SOUTH 2',
#   'NGCOBO NGENZENI WITNESS',
#   'Single Residential (15)',
#   'Residential',
#   '63,000',
#   300),
#  ('53498131',
#   'ERF 877 of BOTHAS HILL',
#   '66013 STREET, QUADI SOUTH 2',
#   'KWELA BATHENI CLERENCE',
#   'Single Residential (15)',
#   'Residential',
#   '63,000',
#   300),
#  ('55534189',
#   'ERF 1315 of MPUMALANGA',
#   '8 400183 STREET, HAMMERS ESTATE',
#   'MKHIZE PEGGY HAZEL NONHLANHLA',
#   'Single Residential (15)',
#   'Residential',
#   '92,000',
#   296),
#  ('04534136',
#   'REM of ERF 34 of MOUNT MORELAND',
#   '30A BOND STREET, MOUNT MORELAND',
#   'GRABE SUSANNA CHRISTINA',
#   'Single Residential (15)',
#   'Residential',
#   '900,000',
#   1934),
#  ('45340156',
#   'ERF 2682 of WATERLOO EXT 9',
#   '7 ONION ROAD, WATERLOO',
#   'SHABANE NONHLANHLA',
#   'Single Residential (15)',
#   'Residential',
#   '240,000',
#   217),
#  ('63534702',
#   'ERF 2040 of UMLAZI Z',
#   '9 IMFE CLOSE, UMLAZI-Z',
#   'NGEMA TSHEKEDI SITHEMBISO',
#   'Single Residential (15)',
#   'Residential',
#   '710,000',
#   424),
#  ('61534295',
#   'ERF 2355 of UMLAZI H',
#   '14 107904 STREET, UMLAZI-H',
#   'KWAZULU GOVERNMENT',
#   'Single Residential (15)',
#   'Residential',
#   '130,000',
#   186),
#  ('61477534',
#   'ERF 1787 of UMLAZI H',
#   '17 107862 STREET, UMLAZI-H',
#   'MAFU SARAH',
#   'Single Residential (15)',
#   'Residential',
#   '130,000',
#   247),
#  ('51534590',
#   'ERF 704 of KWAMASHU L',
#   '131 SIBISI ROAD, KWAMASHU-L',
#   'KWAZULU GOVERNMENT',
#   'Single Residential (15)',
#   'Residential',
#   '160,000',
#   366),
#  ('33534372',
#   'ERF 321 of EMAPLAZINI',
#   '7 109817 STREET, EMAPLAZINI',
#   'MADLOPHA SIDUMO GRIFFTS',
#   'Single Residential (15)',
#   'Residential',
#   '160,000',
#   243),
#  ('33153401',
#   'ERF 2048 of INANDA GLEBE',
#   '34 107617 STREET, INANDA GLEBE',
#   'NGCOBO SIZAKELE RITTA',
#   'Single Residential (15)',
#   'Residential',
#   '380,000',
#   491),
#  ('30534268',
#   'ERF 488 of NTUZUMA C',
#   '9 106587 STREET, NTUZUMA-C',
#   'MBHELE BENEDICTUS THEMBA',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '45,000',
#   300),
#  ('61024534',
#   'ERF 245 of WESTRICH',
#   '41 AMEN STREET, WESTRICH',
#   'GWALA NGENZENI CLEARANCE',
#   'Single Residential (15)',
#   'Residential',
#   '330,000',
#   240),
#  ('81534088',
#   'Portion 13 of ERF 644 of DUIKER FONTEIN',
#   '22 BLACKBURN ROAD, PARKHILL',
#   'LOUIS ANTHONY PAUL JEAN-',
#   'Single Residential (15)',
#   'Residential',
#   '1,140,000',
#   1036),
#  ('58096534',
#   'ERF 519 of BONELA EXT 2',
#   '5 CARLOW ROAD, BONELA',
#   'NEWMATE INVESTMENTS CC',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '530,000',
#   900),
#  ('29108534',
#   'ERF 1086 of SHASTRI PARK',
#   '15 METROPARK PLACE, SHASTRI PARK',
#   'MAHARAJ VINESH',
#   'Single Residential (15)',
#   'Residential',
#   '770,000',
#   249),
#  ('83548534',
#   'ERF 225 of UMGENI PARK',
#   '34 HILLBROW ROAD, UMGENI PARK',
#   'CHAN CHU HUNG',
#   'Single Residential (15)',
#   'Residential',
#   '1,950,000',
#   1201),
#  ('96453405',
#   'REM of Portion 6 of ERF 14263 of DURBAN AIRPORT NO. 14263',
#   'TRAVANCORE DRIVE, DURBAN AIRPORT 14263',
#   'ETHEKWINI MUNICIPALITY (ELECTRICITY)',
#   'Substations (54)',
#   'PSI',
#   '3,280,000',
#   2020),
#  ('53408749',
#   'ERF 299 of DUBE VILLAGE',
#   '10 109395 STREET, DUBES LAND',
#   'DUBE ZENZELE MFUNDO',
#   'Single Residential (15)',
#   'Residential',
#   '97,000',
#   407),
#  ('53409557',
#   'ERF 1077 of NTUZUMA H',
#   '3 OGWAVA LANE, NTUZUMA - H',
#   'MKHIZE BHEKISISA RICHARD',
#   'Single Residential (15)',
#   'Residential',
#   '200,000',
#   358),
#  ('53410364',
#   'ERF 1066 of NTUZUMA H',
#   '31 MANANTSHI AVENUE, NTUZUMA - H',
#   'NGCOBO TERRENCE MTHOKOZISI',
#   'Single Residential (15)',
#   'Residential',
#   '150,000',
#   742),
#  ('53411172',
#   'ERF 1046 of NTUZUMA H',
#   '11 AMAGRAPES GROVE, NTUZUMA - H',
#   'XHAKAZA THEMBISILE GLADYS',
#   'Single Residential (15)',
#   'Residential',
#   '150,000',
#   311),
#  ('53414607',
#   'ERF 1957 of NTUZUMA C',
#   '19 IBHONSI AVENUE, NTUZUMA - C',
#   'CEBEKHULU KHAYELIHLE',
#   'Single Residential (15)',
#   'Residential',
#   '350,000',
#   300),
#  ('45534181',
#   'ERF 2027 of SHALLCROSS EXT 2',
#   '20 NARAN PLACE, SHALLCROSS',
#   'MOODLEY VEERAN',
#   'Single Residential (15)',
#   'Residential',
#   '780,000',
#   650),
#  ('65340281',
#   'ERF 385 of KWADABEKA D',
#   '4 200648 STREET, KWADABEKA-D',
#   'NDLELA TOKOZILE EMILY',
#   'Single Residential (15)',
#   'Residential',
#   '250,000',
#   300),
#  ('65348261',
#   'ERF 395 of KWADABEKA D',
#   '7 200649 STREET, KWADABEKA-D',
#   'BHENGU MYEKENI',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '26,000',
#   300),
#  ('25346097',
#   'Portion 608 of ERF 978 of FARM WATERFALL NO. 978',
#   '23 MAC MAC DRIVE, WATERFALL',
#   'ASHENDEN ARTHUR LIONEL ANDREW',
#   'Single Residential (15)',
#   'Residential',
#   '1,200,000',
#   1986),
#  ('34534164',
#   'ERF 1207 of FOLWENI B',
#   '7 58194 STREET, FOLWENI-B',
#   'ETHEKWINI MUNICIPALITY',
#   'Single Residential (15)',
#   'Residential',
#   '110,000',
#   734),
#  ('37534167',
#   'ERF 740 of FOLWENI C',
#   '157 BHEKIZIYHA ROAD, FOLWENI-C',
#   'ETHEKWINI MUNICIPALITY',
#   'Single Residential (15)',
#   'Residential',
#   '120,000',
#   346),
#  ('59534191',
#   'ERF 5342 of VERULAM EXT 44',
#   '44 GREENWOOD CLOSE, PARKGATE',
#   'TOOLSI SHAKELA',
#   'Single Residential (15)',
#   'Residential',
#   '810,000',
#   689),
#  ('51317534',
#   'Portion 940 of ERF 1575 of COTTON LANDS NO. 1575',
#   ', INANDA NU',
#   'R S A',
#   'Development Phasing Line (95)',
#   'State Trust Land',
#   '370,000',
#   50586),
#  ('60534092',
#   'ERF 1213 of UMLAZI BB',
#   '27 NANDI ROAD, UMLAZI-BB',
#   'NHLUMAYO SIPHIWE DESMOND',
#   'Single Residential (15)',
#   'Residential',
#   '380,000',
#   648),
#  ('60453494',
#   'ERF 385 of UMLAZI',
#   '5 DINGISWAYO PLACE, UMLAZI-BB',
#   'MSANI ETHELINE LINDIWE',
#   'Single Residential (15)',
#   'Residential',
#   '940,000',
#   460),
#  ('32025534',
#   'ERF 1661 of INANDA M',
#   '23 108944 STREET, AMATIKWE',
#   'REGIONAL & LAND AFFAIRS',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '50,000',
#   390),
#  ('30153498',
#   'ERF 1713 of NTUZUMA A',
#   '3 MLANDO ROAD, NTUZUMA-A',
#   'LUTHULI SOLIZITHA PHENDULANI',
#   'Single Residential (15)',
#   'Residential',
#   '180,000',
#   302),
#  ('74003534',
#   'Portion 8507 of ERF 107 of CHATSWORTH',
#   '204 CAMILLUS AVENUE, ARENA PARK',
#   'GOVENDER MARIMUTHU',
#   'Single Residential (15)',
#   'Residential',
#   '690,000',
#   400),
#  ('83043534',
#   'Portion 251 of ERF 6 of DUIKER FONTEIN',
#   '48 JAIN ROAD, KENVILLE',
# ...
#  ('61553485',
#   'ERF 126 of UMLAZI K',
#   '45 NGCOBO ROAD, UMLAZI-K',
#   'NXASANA MPIYONKE ANTWERP',
#   'Single Residential (15)',
#   'Residential',
#   '340,000',
#   358),
#  ('61534700',
#   'ERF 2360 of UMLAZI H',
#   '26 107904 STREET, UMLAZI-H',
#   'KWAZULU GOVERNMENT',
#   'Single Residential (15)',
#   'Residential',
#   '280,000',
#   158),
#  ('51534186',
#   'ERF 700 of KWAMASHU L',
#   '127 SIBISI ROAD, KWAMASHU-L',
#   'KWAZULU GOVERNMENT',
#   'Single Residential (15)',
#   'Residential',
#   '110,000',
#   342),
#  ('51498534',
#   'ERF 340 of KWAMASHU L',
#   '127 NYALA ROAD, KWAMASHU-L',
#   'KWAZULU GOVERNMENT',
#   'Single Residential (15)',
#   'Residential',
#   '210,000',
#   370),
#  ('33534978',
#   'ERF 327 of EMAPLAZINI',
#   '17 SIYABONISANA WALK, EMAPLAZINI',
#   'BIYASE SKHUMBUZO PARTIC',
#   'Single Residential (15)',
#   'Residential',
#   '180,000',
#   267),
#  ('30601534',
#   'ERF 1161 of NTUZUMA C',
#   '105 UJILO GROVE, NTUZUMA-C',
#   'KWAZULU GOVERNMENT',
#   'Single Residential (15)',
#   'Residential',
#   '480,000',
#   300),
#  ('30534773',
#   'ERF 493 of NTUZUMA C',
#   '19 INGCEBO DRIVE, NTUZUMA-C',
#   'S J MALULEKA',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '45,000',
#   570),
#  ('08053467',
#   'ERF 534 of SOUTHGATE',
#   '26 RISEGATE DRIVE, SOUTHGATE',
#   'NAIDOO SIVANAYAGIE',
#   'Single Residential (15)',
#   'Residential',
#   '1,000,000',
#   568),
#  ('55345293',
#   'REM of ERF 1622 of CATO MANOR',
#   '534 KING CETSHWAYO HIGHWAY, WATERVALPARK',
#   'FARAGRO INV PTY LTD',
#   'Single Residential (15)',
#   'Residential',
#   '1,800,000',
#   914),
#  ('50534185',
#   'ERF 1789 of KWAMASHU D',
#   '19 FOREST RING CIRCLE, KWAMASHU-D',
#   'NENE MAFIKA ROBERT',
#   'Single Residential (15)',
#   'Residential',
#   '270,000',
#   461),
#  ('41053400',
#   'ERF 534 of AVOCA HILLS',
#   '135 COURTOWN CRESCENT, AVOCA HILLS',
#   'CEBEKHULU NJABULO WISEMAN HOWARD',
#   'Single Residential (15)',
#   'Residential',
#   '720,000',
#   567),
#  ('61005344',
#   'ERF 53 of WESTRICH',
#   'GUAVARICH CLOSE, WESTRICH',
#   'G J; M MKHIZE',
#   'Single Residential (15)',
#   'Residential',
#   '110,000',
#   360),
#  ('97153460',
#   'ERF 2275 of CORNUBIA',
#   '28A 610707 STREET, CORNUBIA',
#   'DLOKO ANELE CEBATIAN',
#   'Single Residential (15)',
#   'Residential',
#   '220,000',
#   92),
#  ('49534183',
#   'ERF 195 of CLIFFDALE',
#   '30 CLIFFDALE ROAD, CLIFFDALE',
#   'PILLAY VIJAYLUXMI',
#   'Single Residential (15)',
#   'Residential',
#   '2,110,000',
#   79111),
#  ('35534169',
#   'ERF 529 of MPUMALANGA C',
#   '58 DIMBA ROAD, MPUMALANGA-C',
#   'GCABASHE KELINA',
#   'Single Residential (15)',
#   'Residential',
#   '200,000',
#   371),
#  ('46534176',
#   'ERF 3141 of KWAMAKHUTHA A',
#   '4 50101 STREET, KWAMAKHUTA',
#   'UNKNOWN 3141',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '120,000',
#   600),
#  ('55534187',
#   'ERF 2554 of VERULAM EXT 25',
#   '47 ANTELOPE PLACE, MOUNTVIEW',
#   'PARDESI AVIS THERESA',
#   'Single Residential (15)',
#   'Residential',
#   '670,000',
#   236),
#  ('50206534',
#   'Portion 89 of ERF 8318 of AMANZIMTOTI MISSION RESERVE NO. 8318',
#   ', EMANSOMINI',
#   'INGONYAMA TRUST-TRUSTEES',
#   'Multiple Residential (16)',
#   'Residential',
#   '680,000',
#   51529),
#  ('50701534',
#   'ERF 473 of INANDA M',
#   '109 108938 STREET, AMATIKWE',
#   'Regional and Land Affairs',
#   'Single Residential (15)',
#   'Residential',
#   '76,000',
#   465),
#  ('62534599',
#   'ERF 2135 of UMLAZI Q',
#   '41 107994 STREET, UMLAZI-Q',
#   'MHLONGO NOMPUMELELO SAMKELISIWE',
#   'Single Residential (15)',
#   'Residential',
#   '140,000',
#   110),
#  ('62353406',
#   'ERF 125 of UMLAZI Q',
#   '142 UMDLEBE ROAD, UMLAZI-Q',
#   'MBALI NTOMBANA IDA',
#   'Single Residential (15)',
#   'Residential',
#   '290,000',
#   348),
#  ('51075344',
#   'ERF 989 of KWAMASHU H',
#   '62 MTHINI ROAD, KWAMASHU-H',
#   'MSELEKU ZIBUYILE JOYCE',
#   'Single Residential (15)',
#   'Residential',
#   '320,000',
#   458),
#  ('30453468',
#   'ERF 2148 of NTUZUMA B',
#   '20 108291 STREET, NTUZUMA-B',
#   'MCHUNU THOKO MARGARET',
#   'Single Residential (15)',
#   'Residential',
#   '280,000',
#   411),
#  ('26453445',
#   'ERF 1278 of CANESIDE',
#   '27 PENSIDE PLACE, CANESIDE',
#   'NAIDOO MUNIAMAH',
#   'Single Residential (15)',
#   'Residential',
#   '680,000',
#   301),
#  ('70085340',
#   'Portion 853 of ERF 107 of CHATSWORTH',
#   '468 701 ROAD, RISECLIFF',
#   'NAIDOO RAGESHAN',
#   'Single Residential (15)',
#   'Residential',
#   '570,000',
#   368),
#  ('92165349',
#   'REM of ERF 3193 of DURBAN NORTH',
#   '298 FAIRWAY, VIRGINIA',
#   'STARLITE HELICOPTER CORPORATION (PTY) LTD (ETHEKWINI)',
#   'Retail/Offices/Entertainment/ Restaurant (41)',
#   'Business & Commercial',
#   '2,710,000',
#   701),
#  ('05341001',
#   'ERF 12423 of DURBAN',
#   '40 MILNER ROAD, ESSENWOOD',
#   'KING HELEN ANNE MARGUERITE',
#   'Single Residential (15)',
#   'Residential',
#   '1,870,000',
#   545),
#  ('05348071',
#   'ERF 3121 of DURBAN',
#   '55 AVONDALE ROAD, ESSENWOOD',
#   'NAROTH CAZIR',
#   'Single Residential (15)',
#   'Residential',
#   '1,270,000',
#   418),
#  ('93245342',
#   'Portion 56 of ERF 333 of ZEEKOE VALLEI',
#   '54 MYPARK DRIVE, PARLOCK',
#   'THOTARAM RADHIKA',
#   'Single Residential (15)',
#   'Residential',
#   '870,000',
#   557),
#  ('51599534',
#   'ERF 1360 of KWAMASHU L',
#   '218 MBONDWE ROAD, KWAMASHU-L',
#   'MHLONGO BEKISILE CHRISTINA',
#   'Single Residential (15)',
#   'Residential',
#   '410,000',
#   426),
#  ('47534383',
#   'ERF 342 of ASSAGAY',
#   '19 LELLO ROAD, ALVERSTONE',
#   'ADAM STEPHEN DU PLESSIS',
#   'Single Residential (15)',
#   'Residential',
#   '2,130,000',
#   22829),
#  ('44534051',
#   'REM of Portion 7 of ERF 335 of SEA VIEW',
#   '103 BRAESIDE ROAD, SEA VIEW',
#   'GOUS ULRIC RAY',
#   'Single Residential (15)',
#   'Residential',
#   '1,090,000',
#   978),
#  ('02534928',
#   'ERF 319 of ROCKFORD',
#   '16 3RD CRESCENT, ROCKFORD',
#   'MUNIEN SOOBRAMONEY',
#   'Single Residential (15)',
#   'Residential',
#   '610,000',
#   322),
#  ('60962534',
#   'ERF 505 of UMLAZI E',
#   '11 FANA NDLOVU DRIVE, UMLAZI-E',
#   'DLAMINI GIRLIE AGNES',
#   'Single Residential (15)',
#   'Residential',
#   '450,000',
#   391),
#  ('30207534',
#   'ERF 2254 of NTUZUMA A',
#   '140 DUKUZA STREET, NTUZUMA-A',
#   'KWAZULU GOVERNMENT',
#   'Single Residential (15)',
#   'Residential',
#   '160,000',
#   426),
#  ('32429534',
#   'ERF 2660 of NTUZUMA B',
#   '108298 STREET, NTUZUMA-B',
#   'NGCOBO RICHARD NICHOLAS',
#   'Single Residential (15)',
#   'Residential',
#   '350,000',
#   300),
#  ('53412283',
#   'ERF 2136 of NTUZUMA H',
#   '16 SIZIMELE LANE , NTUZUMA - H',
#   'MAPHUMULO HLENGIWE MILLICENT',
#   'Single Residential (15)',
#   'Residential',
#   '340,000',
#   210),
#  ('54534190',
#   'ERF 1439 of RESERVOIR HILLS EXT 5',
#   '183 KIES AVENUE, RESERVOIR HILLS',
#   'GHURBARUN NESHOL',
#   'Single Residential (15)',
#   'Residential',
#   '630,000',
#   720),
#  ('16534049',
#   'REM of ERF 261 of CHELMSFORDVILLE EXT 1',
#   '4 BRIDGET ROAD, CHELMSFORDVILLE',
#   'SCHIRMER KLAUS BERNHARD HEINRICH',
#   'Single Residential (15)',
#   'Residential',
#   '2,400,000',
#   2247),
#  ('39534173',
#   'ERF 785 of MPUMALANGA D',
#   '50 414 STREET, ZAMANI-B',
#   'NGUBO INNET NOMATHEMBA',
#   'Single Residential (15)',
#   'Residential',
#   '360,000',
#   391),
#  ('55342184',
#   'ERF 10097 of LOVU',
#   '62 10455 STREET, ILLOVU',
#   'MCHUNU STANLEY BONGINKOSI',
#   'Single Residential (15)',
#   'Residential',
#   '73,000',
#   409),
#  ('10653421',
#   'ERF 1947 of LOVU',
#   '6 10057 STREET, LOVU',
#   'TWANI LINDENI HAZEL',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '72,000',
#   300),
#  ('15534147',
#   'ERF 3624 of TONGAAT EXT 28',
#   '23 HERCUS AVENUE, BELVEDERE NORTH',
#   'GOVENDER THAVARANI',
#   'Single Residential (15)',
#   'Residential',
#   '640,000',
#   363),
#  ('40534172',
#   'ERF 638 of WATERLOO EXT 2',
#   '9 HORSE ROAD, WATERLOO',
#   'CELE THABISILE PRUDENCE',
#   'Single Residential (15)',
#   'Residential',
#   '200,000',
#   182),
#  ('61770534',
#   'ERF 294 of UMLAZI L',
#   '46 KHALAMAZU ROAD, UMLAZI-L',
#   'MGABI EMMANUEL NKOSINATHI',
#   'Single Residential (15)',
#   'Residential',
#   '370,000',
#   412),
#  ('52085344',
#   'ERF 2195 of KWAMASHU Q',
#   '14 108132 STREET, KWAMASHU-Q',
#   'MAZEKA VITUS MSIZI',
#   'Single Residential (15)',
#   'Residential',
#   '43,000',
#   72),
#  ('50553476',
#   'ERF 2018 of KWAMASHU D',
#   '62 SANGWANA ROAD, KWAMASHU-D',
#   'KUNENE BONGINKOSI LAWRENCE',
#   'Single Residential (15)',
#   'Residential',
#   '770,000',
#   420),
#  ('50453486',
#   'ERF 982 of KWAMASHU D',
#   '119 MKHAMBATHI ROAD, KWAMASHU-D',
#   'DLAMINI EMMANUEL SIPHO',
#   'Single Residential (15)',
#   'Residential',
#   '240,000',
#   260),
#  ('31534471',
#   'ERF 371 of INANDA B',
#   '15 SHUKUMA CLOSE, INANDA-B',
#   'MABASO GUGU PRISCILLA',
#   'Single Residential (15)',
#   'Residential',
#   '280,000',
#   667),
#  ('00028534',
#   'ERF 286 of CHESTERVILLE',
#   '10 LANGALIBALELE ROAD, BLACKHURST',
#   'MTHEMBU FRANK CONFERENCE',
#   'Single Residential (15)',
#   'Residential',
#   '620,000',
#   469),
#  ('21645340',
#   'ERF 389 of NORTHCROFT',
#   '101 AVALEN CRESCENT, NORTHCROFT',
#   'THIVESHAN NAIDOO',
#   'Single Residential (15)',
#   'Residential',
#   '660,000',
#   198),
#  ('21534644',
#   'ERF 884 of LONGCROFT',
#   '41 UPPERCROFT ROAD, LONGCROFT',
#   'GOPAL SEWCHARAN',
#   'Single Residential (15)',
#   'Residential',
#   '860,000',
#   200),
#  ('70534890',
#   'Portion 5348 of ERF 107 of CHATSWORTH',
#   '9 ALENTIA GROVE, MOORTON',
#   'MUNIEN MEANDRAIN',
#   'Single Residential (15)',
#   'Residential',
#   '430,000',
#   209),
#  ('95342506',
#   'ERF 709 of GLENASHLEY',
#   '6 DOREEN CRESCENT, GLENASHLEY',
#   'THE PHOENIX FAMILY TRUST',
#   'Single Residential (15)',
#   'Residential',
#   '2,820,000',
#   1012),
#  ('95348061',
#   'ERF 720 of GLENASHLEY',
#   '4 DOREEN CRESCENT, GLENASHLEY',
#   'STEINBACH SHIRLEY MAYE',
#   'Single Residential (15)',
#   'Residential',
#   '2,900,000',
#   1012),
#  ('29534238',
#   'Portion 2 of ERF 1440 of WENTWORTH',
#   '60 WINCHELSEA AVENUE, WENTWORTH',
#   'BOYES MARK JOHN LUCAS',
#   'Single Residential (15)',
#   'Residential',
#   '1,020,000',
#   831),
#  ('31855348',
#   'ERF 1559 of INANDA F',
#   '10 108883 STREET, AMATIKWE',
#   'REGIONAL & LAND AFFAIRS',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '100,000',
#   750),
#  ('30534874',
#   'ERF 494 of NTUZUMA C',
#   '4 UMTHELEKISI ROAD, NTUZUMA-C',
#   'MKHIZE JUDITH NTOMBI',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '39,000',
#   300),
#  ('53413293',
#   'ERF 2280 of NTUZUMA H',
#   '28 110105 STREET, NTUZUMA - H',
#   'MANUKUZA ISABEL JABISILE',
#   'Single Residential (15)',
#   'Residential',
#   '440,000',
#   298),
#  ('53413697',
#   'ERF 1939 of NTUZUMA G',
#   '33A XOLANI NGCOBO WALK, NTUZUMA - G',
#   'MTHEMBU NOKUTHULA GLENROSE',
#   'Retail/Offices/Entertainment/ Restaurant (41)',
#   'Business & Commercial',
#   '450,000',
#   297),
#  ('45346120',
#   'ERF 2935 of SHALLCROSS EXT 5',
#   '82 SAFFRON DRIVE, NORTHDENE',
#   'PILLAY M (DSB)',
#   'Single Residential (15)',
#   'Residential',
#   '520,000',
#   300),
#  ('55343100',
#   'Portion 5 of ERF 176 of RESERVOIR HILLS',
#   '124 DUNKELD ROAD, RESERVOIR HILLS',
#   'DUIJMONI ?',
#   'Single Residential (15)',
#   'Residential',
#   '1,490,000',
#   1106),
#  ('60534196',
#   'ERF 496 of KWADABEKA J',
#   '12 200734 STREET, KWADABEKA-J',
#   'CELE DUMISANI ERNEST',
#   'Single Residential (15)',
#   'Residential',
#   '95,000',
#   278),
#  ('30534164',
#   'ERF 1598 of MPUMALANGA A',
#   '61 SABELLA ROAD, MPUMALANGA-A',
#   'MNCWABE JOHANNES BONGINKOSI',
#   'Single Residential (15)',
#   'Residential',
#   '170,000',
#   348),
#  ('01948534',
#   'ERF 1019 of AMANZIMTOTI EXT 2',
#   '19 YORK STREET, AMANZIMTOTI',
#   'AMANZIMTOTI SR-CC',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '140,000',
#   483),
#  ('45342174',
#   'ERF 1355 of KWAMAKHUTHA A',
#   '42 MFUNDI MNGADI DRIVE, KWAMAKHUTA',
#   'MKUNGO MVAKWENDLU GIDEON',
#   'Single Residential (15)',
#   'Residential',
#   '510,000',
#   329),
#  ('16534148',
#   'ERF 15 of GANDHINAGAR',
#   '2 TAGORE STREET, GHANDINAGER',
#   'MATHURA SHARITHA',
#   'Single Residential (15)',
#   'Residential',
#   '1,060,000',
#   1056),
#  ('65534197',
#   'REM of ERF 356 of VERULAM',
#   '56 ALOE DRIVE, VERULAM',
#   'PROUD PROPS 43 CC',
#   'Industrial (45)',
#   'Industrial',
#   '2,520,000',
#   4112),
#  ('51753457',
#   'ERF 1436 of KWAMASHU M',
#   '16 NTETHE ROAD, KWAMASHU-M',
#   'MBATHA MZONJANI ELLIOT',
#   'Single Residential (15)',
#   'Residential',
#   '460,000',
#   447),
#  ('31453469',
#   'ERF 2338 of INANDA A',
#   '21 HLALELE ROAD, INANDA-A',
#   'MAJOLO JOHN',
#   'Single Residential (15)',
#   'Residential',
#   '190,000',
#   300),
#  ('32053491',
#   'ERF 535 of TRENANCE MANOR',
#   '41 BRANCHMANOR GARDENS, TRENANCE MANOR',
#   'DULOO DHANIRAM BRIJMOHUN',
#   'Single Residential (15)',
#   'Residential',
#   '580,000',
#   338),
#  ('73534388',
#   'Portion 185 of ERF 101 of CHATSWORTH',
#   '153 EQUALITY AVENUE, CROFTDENE',
#   'PILLAY MUNSAMI',
#   'Single Residential (15)',
#   'Residential',
#   '290,000',
#   209),
#  ('75660534',
#   'Portion 7 of ERF 344 of SPRINGFIELD',
#   '73 MUSCARI ROAD, SPRINGFIELD',
#   'PILLAY KULLIAMAH',
#   'Single Residential (15)',
#   'Residential',
#   '430,000',
#   584),
#  ('75346021',
#   'Portion 98 of ERF 328 of SPRINGFIELD',
#   'CEDARVILLE ROAD                 , CLARE HILLS',
#   'WILLIAMS ANGELIQUE LYNELLE',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '120,000',
#   945),
#  ('26515348',
#   'Portion 350 of ERF 105 of WENTWORTH',
#   '4 IXORA ROAD, AUSTERVILLE',
#   'OGLE PERCIVAL LAMSON',
#   'Single Residential (15)',
#   'Residential',
#   '900,000',
#   451),
#  ('26534740',
#   'ERF 1777 of MEREWENT',
#   '10 INDORE ROAD, MEREWENT',
#   'DUTT SHANTAL BHADAR',
#   'Single Residential (15)',
#   'Residential',
#   '1,010,000',
#   334),
#  ('26595340',
#   'Portion 213 of ERF 14836 of CLAIRWENT THREE NO. 14836',
#   '7 JHELUM ROAD, MEREWENT',
#   'GOVENDER SIGAMONEY',
#   'Single Residential (15)',
#   'Residential',
#   '750,000',
#   344),
#  ('51353497',
#   'ERF 1152 of KWAMASHU K',
#   '139 SIKWEHLE ROAD, KWAMASHU-K',
#   'RADEBE ESTHER',
#   'Single Residential (15)',
#   'Residential',
#   '340,000',
#   260),
#  ('30553458',
#   'ERF 680 of NTUZUMA C',
#   '9 UQOMO WALK, NTUZUMA-C',
#   'KWAZULU GOVERNMENT',
#   'Single Residential (15)',
#   'Residential',
#   '190,000',
#   300),
#  ('00253457',
#   'ERF 25834 of PINETOWN',
#   '23 SARJOO DRIVE, SITHUNDU HILLS',
#   'NGCOBO BHEKINKOSI STEPHEN',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '50,000',
#   347),
#  ('97423534',
#   'ERF 1866 of CORNUBIA',
#   '114 610718 STREET, CORNUBIA',
#   'MLAMBI SPHIWE',
#   'Single Residential (15)',
#   'Residential',
#   '260,000',
#   78),
#  ('55340170',
#   'REM of ERF 4659 of RESERVOIR HILLS',
#   '14 PLUMSTEAD CRESCENT, RESERVOIR HILLS',
#   'AK-EMPIRE TRUST',
#   'Vacant Land (47)',
#   'Vacant Land',
#   '480,000',
#   8470),
#  ('05346077',
#   'ERF 3017 of KLOOF EXT 14',
#   '29 MARIGOLD LANE, MOTALABAD',
#   'PILLAY PRAGALASAN SAMBASIVAN',
#   'Single Residential (15)',
#   'Residential',
#   '450,000',
#   777),
#  ('61534195',
#   'ERF 803 of LOWER LANGEFONTEIN',
#   '70 MADIBA ROAD, MAROMENI',
#   'NTSHANGASE EVELYN',
#   'Single Residential (15)',
#   'Residential',
#   '110,000',
#   597),
#  ('65340174',
#   'ERF 407 of MAGABENI A',
#   '17 PHEPHETHA ROAD, MAGABHENI-A',
#   'MNGOMEZULU PRECIOUS GUGWINI',
#   'Single Residential (15)',
#   'Residential',
#   '170,000',
#   557),
#  ('29534161',
#   'ERF 493 of LA LUCIA EXT 1',
#   '17 OAKLEIGH AVENUE, LA LUCIA',
#   'KLERK NICOLAAS FERREIRA DE',
#   'Single Residential (15)',
#   'Residential',
#   '4,390,000',
#   1227),
#  ('63253417',
#   'ERF 268 of UMLAZI W',
#   '11 UMSINSI GROVE, UMLAZI-W',
#   'MABHIDA GUBUKWAZI WILBERT',
#   'Single Residential (15)',
#   'Residential',
#   '620,000',
#   402),
#  ('63135348',
#   'ERF 782 of UMLAZI V',
#   '16 UVE ROAD, UMLAZI-V',
#   'CELE NKOSINATHI EMMANUEL',
#   'Single Residential (15)',
#   'Residential',
#   '320,000',
#   1030),
#  ('61165343',
#   'ERF 374 of UMLAZI G',
#   'IMPAKA WAY, UMLAZI-G',
#   'CIBANE ANNACETTA DELISILE',
#   'Single Residential (15)',
#   'Residential',
#   '290,000',
#   383),
#  ('33553461',
#   'ERF 512 of EMAPLAZINI',
#   '138 107640 STREET, EMAPLAZINI',
#   'GCABASHE BONGIWE CAROLINE',
#   'Single Residential (15)',
#   'Residential',
#   '120,000',
#   122),
#  ('10128534',
#   'ERF 1353 of LAMONTVILLE',
#   '2 MALINGA ROAD, LAMONT',
#   'ETHEKWINI MUNICIPALITY',
#   'Single Residential (15)',
#   'Residential',
#   '340,000',
#   12971),
#  ('32153481',
#   'ERF 1535 of TRENANCE MANOR',
#   '96 PALMVIEW DRIVE, TRENANCE MANOR',
#   'ETHEKWINI MUNICIPALITY',
#   'Single Residential (15)',
#   'Residential',
#   '580,000',
#   250),
#  ('20653419',
#   'ERF 73 of REDFERN',
#   '219 FERNHAM DRIVE, REDFERN',
#   'KISTEN CRAIG',
#   'Single Residential (15)',
#   'Residential',
#   '790,000',
#   412),
#  ...]
